# %%
import json
import csv
import zipfile
import re
import requests

# %% [markdown]
# # Excluding entities: step 1
# * Entities that have certain values of "instance of" and "subclass of" ("to_exclude.json")
# * Entities without any entity terms

# %%
# reading the file with the P31 and P279 values to exlude

with open("to_exlude.json") as jf_exlude:
    to_exclude = json.load(jf_exlude)

# %% [markdown]
# ### EN

# %%
# unzipping the search results to a local directory
with zipfile.ZipFile("wikidata_search_results_en.json.zip","r") as unzip:
    unzip.extractall("/Users/anesterov/wd")

# %%
# reading the results file
with open("/Users/anesterov/wd/wikidata_search_results.json") as jf:
    wd_search_results_en = json.load(jf)

# %%
# reading the file with the query terms and putting them in a list

with open("wikidata_query_terms_en.txt","r") as txt_file:
    terms_en = txt_file.read()
    
queried_terms_en = [s.strip("\'") for s in terms_en.lstrip("[").rstrip("]").split(", ")]

# %%
# storing all the entities to exclude from the results in a list

entities_to_exlude = []

# %%
# iterating over the claim files
# claims for every term are stored in separate files (they were saved in the previous step, 'query_wikidata_en_nl.ipynb')
# claims are stored in list of dicts
# the number of dicts corresponds to the number of requests made to retrieve claims

for term in queried_terms_en:
    print(term)
    # set your path to the claims directory
    with open(f"/claims_en/{term}_claims.json","r") as jf:
        claims_file = json.load(jf)
        
    if claims_file["entities"] != []: # if there are claims

        for i in claims_file["entities"]:
            for e_id, values in i.items():
                if 'claims' in values:
                    for v in values['claims'].values():
                        for l in v:
                            if 'datavalue' in l['mainsnak']:
                                # if the values of P31 or P279 match the ids to exclude,
                                # add them to the list 'entities_to_exlude'
                                if (l['mainsnak']['property'] == 'P31' or l['mainsnak']['property'] == 'P279') \
                                and l['mainsnak']['datavalue']['value']['id'] in to_exclude.keys():
                                    entities_to_exlude.append(e_id)
        print(len(entities_to_exlude),"\n")
# Out:
# calcutta
# 398
#
# "first nation"
# 407
#
# indian
# 956
#
# historic
# 1060
#
# headhunter
# 1099
#
# imazighen
# 1100
#
# "second world"
# 1271
#
# exotic
# 2202
#
# khoisan
# 2212
#
# "person of color"
# 2212
#
# coolie
# 2246
#
# half-breed
# 2259
#
# immigrant
# 3047
#
# root
# 5845
#
# footman
# 5861
#
# amazigh
# 5865
#
# "little persons"
# batavia
# 5900
#
# enslaved
# 5991
#
# asian
# 6714
#
# "people of color"
# 6715
#
# allochtoon
# 6716
#
# "little person"
# 6717
#
# homosexual
# 6960
#
# page
# 8463
#
# "spiritual healer"
# 8463
#
# aboriginal
# 8721
#
# race
# 8907
#
# berber
# 9012
#
# half-blood
# 9020
#
# oriental
# 9562
#
# muslim
# 10158
#
# intersex
# 10220
#
# "torres strait"
# 10256
#
# mulatto
# 10272
#
# lgbt
# 10596
#
# servant
# 10836
#
# maroon
# 10970
#
# "medicine man"
# 10986
#
# lilliputian
# 10995
#
# "ethnic group"
# 11021
#
# black
# 13665
#
# eskimo
# 13790
#
# "little people"
# 13797
#
# "mixed race"
# 13805
#
# "third world"
# 13949
#
# "developing nation"
# 13951
#
# primitivism
# 13966
#
# barbarian
# 14110
#
# trans
# 19274
#
# madras
# 19465
#
# kaffir
# 19482
#
# mestizo
# 19501
#
# caucasian
# 19694
#
# "people with disabilities"
# 19760
#
# ethnicity
# 21252
#
# disabled
# 21599
#
# colored
# 21740
#
# primitive
# 22545
#
# mongoloid
# 22555
#
# burma
# 22931
#
# mumbai
# 23073
#
# pygmy
# 23553
#
# western
# 25313
#
# "first nations"
# 25335
#
# mohammedan
# 25343
#
# roma
# 25468
#
# "medicine men"
# 25475
#
# transvestite
# 25480
#
# slave
# 26269
#
# queer
# 26600
#
# "southern rhodesia"
# 26649
#
# indigenous
# 27664
#
# homo
# 44360
#
# hermaphrodite
# 44483
#
# gypsy
# 44763
#
# moor
# 45484
#
# descent
# 45710
#
# "bush negro"
# métis
# 45870
#
# "full blood"
# 45871
#
# indo
# 46744
#
# dwarfism
# 49380
#
# negro
# 50463
#
# inuit
# 50528
#
# gay
# 52245
#
# cross-dresser
# 52248
#
# "first world"
# 52455
#
# native
# 55751
#
# dwarf
# 55755
#
# tribe
# 62124
#
# "low-income country"
# 62131
#
# discover
# 63425
#
# hottentot
# 63457
#
# traditional
# 65040
#
# indo-european
# 65120
#
# retarded
# 65314
#
# white
# 68146
#
# "differently abled"
# 68147
#
# "ethnic groups"
# 68212
#
# baboo
# 68265
#
# bombay
# 68581
#
# handicap
# 68928
#
# "short stature"
# 68993

# %%
len(entities_to_exlude)
# Out:
# 68993

# %% [markdown]
# ### NL

# %%
# unzipping the search results to a local directory
with zipfile.ZipFile("wikidata_search_results_nl.json.zip","r") as unzip:
    # set your path
    unzip.extractall('')

# %%
# reading the results file
with open("/Users/anesterov/wd/wikidata_search_results_nl.json") as jf:
    wd_search_results_nl = json.load(jf)

# %%
# reading the file with the query terms and putting them in a list

with open("wikidata_query_terms_nl.txt","r") as txt_file:
    terms_nl = txt_file.read()
    
queried_terms_nl = terms_nl.split('\n')

# %%
# storing all the NL entities to exclude from the results in a list

entities_to_exclude_nl = []

# %%
# iterating over the claim files
# claims for every term are stored in separate files
# claims are stored in list of dicts
# the number of dicts corresponds to the number of requests made to retrieve claims

for term in queried_terms_nl:
    print(term)
    with open(f"/Users/anesterov/claims_nl/{term}_claims.json","r") as jf:
        claims_file = json.load(jf)
        
    if claims_file["entities"] != []: # if there are claims

        for i in claims_file["entities"]:
            for e_id, values in i.items():
                if 'claims' in values:
                    for v in values['claims'].values():
                        for l in v:
                            if 'datavalue' in l['mainsnak']:
                                if (l['mainsnak']['property'] == 'P31' or l['mainsnak']['property'] == 'P279') \
                                and l['mainsnak']['datavalue']['value']['id'] in to_exclude.keys():
                                    entities_to_exclude_nl.append(e_id)
        print(len(entities_to_exclude_nl),"\n")
# Out:
# pages
# 57
#
# page
# 57
#
# homo
# 135
#
# wester
# 251
#
# westers
# 251
#
# indiaan
# 255
#
# roma
# 255
#
# wit
# 337
#
# wits
# 337
#
# witter
# 337
#
# trans
# 1504
#
# oriëntaler
# 1527
#
# "etnische groep"
# 1528
#
# homo's
# 5763
#
# ras
# 11874
#
# historische
# 11930
#
# lgbt
# 11934
#
# moor
# 11944
#
# gay
# 11986
#
# gayer
# 11986
#
# gays
# 11987
#
# historisch
# 11996
#
# oriëntale
# 12523
#
# blank
# 12778
#
# blanker
# 12779
#
# blanks
# 12779
#
# indo
# 12783
#
# historischer
# 12790
#
# indischer
# 12938
#
# indische
# 13120
#
# mumbai
# 13125
#
# koelies
# 13200
#
# witte
# 13725
#
# ontdekken
# 13725
#
# aboriginal
# 13733
#
# aboriginals
# gemengde
# 13735
#
# roots
# 14049
#
# inlander
# 14119
#
# inlanders
# 14119
#
# calcutta
# 14124
#
# bombay
# 14128
#
# zwarte
# 14471
#
# handicap
# 14491
#
# handicaps
# stam
# 14954
#
# madras
# 14956
#
# birma
# 14978
#
# queer
# 14983
#
# witten
# 14996
#
# zwart
# 15095
#
# zwarts
# berber
# 15097
#
# berbers
# aziatische
# 15200
#
# inuit
# 15201
#
# gaye
# 15283
#
# eskimo
# 15287
#
# batavia
# 15289
#
# marron
# 15398
#
# marrons
# rast
# 15445
#
# métis
# 15445
#
# traditionele
# 15445
#
# indisch
# 15454
#
# knecht
# 15472
#
# knechts
# aziatisch
# 15489
#
# gemengd
# 15496
#
# gemengds
# mesties
# 15498
#
# japs
# 15552
#
# jap
# moren
# 15565
#
# rasse
# 15571
#
# slaven
# 15591
#
# blanke
# 15629
#
# traditioneel
# 15629
#
# traditioneels
# indo's
# stammen
# 15640
#
# dwerg
# 15647
#
# neger
# 15659
#
# negers
# bediende
# 15661
#
# bediendes
# kaukasische
# 15714
#
# amazigh
# 15714
#
# afkomst
# 15714
#
# zigeuner
# 15726
#
# zigeuners
# mongool
# 15728
#
# wittere
# 15732
#
# moslim
# 15732
#
# moslims
# inheemse
# 15737
#
# pygmee
# 15756
#
# westerse
# 15759
#
# indianen
# 15761
#
# kaukasisch
# 15764
#
# rassen
# 15770
#
# raste
# 15781
#
# barbaren
# 15787
#
# inuk
# 15796
#
# hottentot
# 15796
#
# exotische
# 15813
#
# slavernij
# 15814
#
# slaaf
# 15817
#
# yup’ik
# 15818
#
# alutiiq
# 15819
#
# eskimo's
# gehandicapten
# 15819
#
# mongolen
# 15822
#
# homoseksualiteit
# 15823
#
# kalaallit
# 15826
#
# khoisan
# mulat
# 15828
#
# inheems
# 15831
#
# dwergen
# 15834
#
# primitieve
# 15837
#
# rasser
# 15839
#
# iñupiat
# 15841
#
# exotisch
# 15843
#
# gekleurde
# 15844
#
# oriëntaal
# 15844
#
# oriëntaals
# kaukasischer
# 15851
#
# zuid-rhodesië
# 15851
#
# halfbloed
# 15857
#
# primitief
# 15858
#
# primitiefs
# crossdresser
# 15859
#
# etniciteit
# 15859
#
# ontwikkelingslanden
# 15859
#
# barbaar
# 15859
#
# hottentotten
# 15864
#
# kaffer
# 15868
#
# kaffers
# baboe
# 15869
#
# baboes
# bedienden
# 15869
#
# oriëntaalse
# 15869
#
# exotischer
# 15873
#
# gehandicapte
# 15874
#
# homoseksueel
# 15874
#
# homoseksueels
# homoseksuele
# 15874
#
# zwarten
# 15876
#
# gekleurd
# 15876
#
# gekleurds
# medicijnman
# 15876
#
# jappenkamp
# 15876
#
# knechten
# 15876
#
# volbloed
# 15877
#
# homoseksuelen
# imazighen
# primitivisme
# 15878
#
# transen
# 15880
#
# bediend
# 15880
#
# "derde wereld"
# 15880
#
# dwerggroei
# hermafrodiet
# 15880
#
# pygmeeën
# 15880
#
# allochtone
# 15880
#
# intersekse
# "met een beperking"
# 15880
#
# "politionele actie"
# 15880
#
# travestiet
# 15880
#
# allochtoon
# allochtoons
# indo-europeanen
# koppensneller
# 15880
#
# koppensnellers
# mulatten
# 15880
#
# ontwikkelingsland
# 15880
#
# "straat torres"
# achterlijk
# 15881
#
# achterlijks
# bosneger
# 15882
#
# bosnegers
# islamieten
# 15882
#
# "japans interneringskamp"
# 15882
#
# "japans kamp"
# 15882
#
# jappen
# 15882
#
# "kleine mensen"
# 15884
#
# lilliputter
# 15884
#
# lilliputters
# oriëntalere
# 15884
#
# "tweede wereld"
# 15884
#
# allochtonen
# boslandcreool
# downsyndroom
# "eerste wereld"
# indischere
# 15884
#
# indo-europeaan
# islamiet
# jappenkampen
# koelie
# lagelonenland
# 15884
#
# mestiezen
# mohammedaan
# mohammedanen
# rassere
# 15884
#
# volbloeden
# 15885
#
# witste
# 15885
#
# yupighyt

# %%
len(entities_to_exclude_nl)
# Out:
# 15885

# %% [markdown]
# ## Before step 2: requesting additional claims
# * Not all the entities have claims, additional requests are needed
# * Check if an entity has claims, if not send a request

# %% [markdown]
# ### EN

# %% [markdown]
# #### checking which entities have missing claims

# %%
# reading the cleaned file
with open("/Users/anesterov/wd/wikidata_search_results_en_clean.json") as jf:
    wd_en_clean = json.load(jf)

# %%
# list of all entities with claims (across all the files)

all_entities_with_claims = []

for query_term in wd_en_clean.keys():
    
    with open(f"/Users/anesterov/claims_en/{query_term}_claims.json","r") as jf:
        claims_file = json.load(jf)
        
    for claim_list in claims_file["entities"]:
        all_entities_with_claims.extend(list(claim_list.keys()))

# %%
# dict {"query_word":[entities_without_claims]}

no_claims = {}

for query_term,value in wd_en_clean.items():
    # list of entities per query word
    list_of_entities_per_term = [i['title'] for i in value.values()] 
    print("term: ", query_term, "|", "total entities: ", len(list_of_entities_per_term))
    
    # checking which entities do not have claims
    entities_without_claims = []
    for i in list_of_entities_per_term:
        if i not in list(set(all_entities_with_claims)):
            entities_without_claims.extend([i])
    
    print("no claims: ", len(entities_without_claims))
    
    if entities_without_claims != []:
        no_claims[query_term] = entities_without_claims
# Out:
# term:  cross-dresser | total entities:  27
# no claims:  0
# term:  "little person" | total entities:  2
# no claims:  0
# term:  "second world" | total entities:  747
# no claims:  0
# term:  indigenous | total entities:  3860
# no claims:  0
# term:  enslaved | total entities:  1986
# no claims:  0
# term:  disabled | total entities:  1074
# no claims:  0
# term:  footman | total entities:  60
# no claims:  0
# term:  transvestite | total entities:  24
# no claims:  0
# term:  discover | total entities:  4390
# no claims:  0
# term:  "short stature" | total entities:  225
# no claims:  0
# term:  amazigh | total entities:  95
# no claims:  0
# term:  "medicine men" | total entities:  10
# no claims:  0
# term:  "torres strait" | total entities:  187
# no claims:  0
# term:  traditional | total entities:  7256
# no claims:  0
# term:  moor | total entities:  5403
# no claims:  0
# term:  "third world" | total entities:  103
# no claims:  0
# term:  ethnicity | total entities:  7509
# no claims:  3
# term:  homo | total entities:  983
# no claims:  1
# term:  berber | total entities:  600
# no claims:  1
# term:  slave | total entities:  3146
# no claims:  1
# term:  native | total entities:  5265
# no claims:  2
# term:  caucasian | total entities:  568
# no claims:  0
# term:  eskimo | total entities:  441
# no claims:  0
# term:  hottentot | total entities:  30
# no claims:  0
# term:  "low-income country" | total entities:  7
# no claims:  0
# term:  baboo | total entities:  35
# no claims:  0
# term:  calcutta | total entities:  1388
# no claims:  0
# term:  descent | total entities:  9419
# no claims:  1
# term:  root | total entities:  4110
# no claims:  0
# term:  batavia | total entities:  425
# no claims:  1
# term:  pygmy | total entities:  75
# no claims:  0
# term:  "little people" | total entities:  47
# no claims:  0
# term:  dwarf | total entities:  1629
# no claims:  0
# term:  servant | total entities:  9043
# no claims:  2
# term:  negro | total entities:  5791
# no claims:  0
# term:  intersex | total entities:  204
# no claims:  0
# term:  mongoloid | total entities:  10
# no claims:  0
# term:  "differently abled" | total entities:  4
# no claims:  0
# term:  "mixed race" | total entities:  20
# no claims:  0
# term:  oriental | total entities:  6973
# no claims:  2

# %%
# 22 terms have missing claims
with open("no_claims.json","w") as json_write:
    json.dump(no_claims, json_write)

# %% [markdown]
# #### NL

# %% [markdown]
# #### checking which entities have missing claims

# %%
# reading the cleaned file
with open("/Users/anesterov/wd/wikidata_search_results_nl_clean.json") as jf:
    wd_nl_clean = json.load(jf)

# %%
# list of all entities with claims (across all the files)

all_entities_with_claims_nl = []

for query_term in wd_nl_clean.keys():
    
    with open(f"/Users/anesterov/claims_nl/{query_term}_claims.json","r") as jf:
        claims_file = json.load(jf)
        
    for claim_list in claims_file["entities"]:
        all_entities_with_claims_nl.extend(list(claim_list.keys()))

# %%
len(all_entities_with_claims_nl)
# Out:
# 104600

# %%
# dict {"query_word":[entities_without_claims]}

no_claims_nl = {}

for query_term,value in wd_nl_clean.items():
    # list of entities per query word
    list_of_entities_per_term = [i['title'] for i in value.values()] 
    print("term: ", query_term, "|", "total entities: ", len(list_of_entities_per_term))
    
    # checking which entities do not have claims
    entities_without_claims = []
    for i in list_of_entities_per_term:
        if i not in list(set(all_entities_with_claims_nl)):
            entities_without_claims.extend([i])
    
    print("no claims: ", len(entities_without_claims))
    
    if entities_without_claims != []:
        no_claims_nl[query_term] = entities_without_claims
# Out:
# term:  bediend | total entities:  5
# no claims:  0
# term:  lilliputters | total entities:  2
# no claims:  1
# term:  mesties | total entities:  281
# no claims:  2
# term:  zwarte | total entities:  800
# no claims:  168
# term:  allochtoons | total entities:  2
# no claims:  2
# term:  moren | total entities:  113
# no claims:  9
# term:  rasse | total entities:  129
# no claims:  46
# term:  gay | total entities:  3013
# no claims:  2899
# term:  wit | total entities:  9774
# no claims:  87
# term:  travestiet | total entities:  4
# no claims:  1
# term:  homo | total entities:  553
# no claims:  552
# term:  aboriginals | total entities:  855
# no claims:  840
# term:  mohammedaan | total entities:  1
# no claims:  1
# term:  marron | total entities:  248
# no claims:  22
# term:  iñupiat | total entities:  13
# no claims:  17

# %%
# checking if the NL claims are not in the EN claims also

no_claims_nl_request = {}
for key,list_of_entities in no_claims_nl.items():
    not_found = [i for i in list_of_entities if i not in all_entities_with_claims]
    if not_found != []:
        no_claims_nl_request[key] = not_found

# %%
# 19 NL terms are missing claims
len(no_claims_nl_request)
# Out:
# 19

# %% [markdown]
# ### Requesting the missing claims

# %% [markdown]
# #### EN

# %%
# 'wbgetentities': constant params
url = "https://www.wikidata.org/w/api.php"
params = {"action":"wbgetentities",
          "ids":"", # string of entities (max=50) goes here
          "props":"claims",
          "languages":"en",
          "format":"json"
         }
headers = {"user-agent":"bot getting claims of the requested entities (CWI; Human-Centered Data Analytics; nesterov@cwi.nl)"}

# %%
list_of_requested_entities = []

# %%
additional_claims = {}

for term, no_claims_list in no_claims.items():
    
    params["ids"] = ""
    
    # for debugging
    
    print("term:",term,"|","entities:",len(no_claims_list))

# - CONDITIONS - #

    # if len of the list > 50 and there's a remainder
    if len(no_claims_list) > 50 and len(no_claims_list) % 50 > 0:
        loops = len(no_claims_list) // 50 + 1 # add another loop for requests
        
    # if len of the list > 50 and no remainder    
    if len(no_claims_list) > 50 and len(no_claims_list) % 50 == 0:
        loops = len(no_claims_list) // 50
        
    # otherwise loops = 1 (len < 50 or len = 50)    
    if len(no_claims_list) < 50:
        loops = 1
        
    # for debugging
    
    print("loops:",loops)
        
# - REQUEST LOOPS - #   
        
    # counters to slice list_of_entities
    start = 0 
    end = 0
    query_result_list = []
    
    for i in range(0,loops):
        ids_string = "" # putting Qs in one string
        end = end + 50

        for q in no_claims_list[start:end]:
            if q not in list_of_requested_entities:
                ids_string = ids_string + f"{q}|"
                list_of_requested_entities.append(q) # remebering requested entities to prevent duplicates

        start = start + 50

        # updating params

        params["ids"] = ids_string.rstrip("|")

        # sending a request
        d = requests.get(url,params=params,headers=headers)
        claims = d.json() # claims per request
        
        if 'entities' in claims:
            query_result_list.append(claims['entities']) # saving all claims
    
    # for debugging        
    print("actual_results:",len(query_result_list),[len(i) for i in query_result_list])

# - SAVING RESULTS - #
        
    additional_claims[term] = query_result_list
# Out:
# term: historic | entities: 2760
# loops: 56
# actual_results: 56 [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 10]
# term: "first nations" | entities: 1
# loops: 1
# actual_results: 0 []
# term: indo-european | entities: 1
# loops: 1
# actual_results: 0 []
# term: asian | entities: 7
# loops: 1
# actual_results: 0 []
# term: trans | entities: 3
# loops: 1
# actual_results: 0 []
# term: race | entities: 1
# loops: 1
# actual_results: 0 []
# term: indo | entities: 2
# loops: 1
# actual_results: 0 []
# term: "ethnic group" | entities: 1
# loops: 1
# actual_results: 0 []
# term: western | entities: 8
# loops: 1
# actual_results: 0 []
# term: mumbai | entities: 1
# loops: 1
# actual_results: 0 []
# term: black | entities: 8
# loops: 1
# actual_results: 0 []
# term: tribe | entities: 2
# loops: 1
# actual_results: 0 []
# term: burma | entities: 1
# loops: 1
# actual_results: 0 []
# term: ethnicity | entities: 3
# loops: 1
# actual_results: 0 []
# term: homo | entities: 1
# loops: 1
# actual_results: 0 []
# term: berber | entities: 1
# loops: 1
# actual_results: 0 []
# term: slave | entities: 1
# loops: 1
# actual_results: 0 []
# term: native | entities: 2
# loops: 1
# actual_results: 0 []
# term: descent | entities: 1
# loops: 1
# actual_results: 0 []
# term: batavia | entities: 1
# loops: 1
# actual_results: 0 []
# term: servant | entities: 2
# loops: 1
# actual_results: 0 []
# term: oriental | entities: 2
# loops: 1
# actual_results: 0 []

# %%
# merging additional claims with all the claims

with open('/Users/anesterov/claims_en/merged_claims_en.json', 'r') as jf:
    all_claims = json.load(jf)

# %%
all_claims['historic'].extend(additional_claims['historic'])

# %%
# rewriting the resulting file
with open('/Users/anesterov/claims_en/merged_claims_en.json', 'w') as output_file:
    json.dump(all_claims, output_file)

# %% [markdown]
# #### NL

# %%
# 'wbgetentities': constant params
url = "https://www.wikidata.org/w/api.php"
params = {"action":"wbgetentities",
          "ids":"", # string of entities (max=50) goes here
          "props":"claims",
          "languages":"en",
          "format":"json"
         }
headers = {"user-agent":"bot getting claims of the requested entities (CWI; Human-Centered Data Analytics; nesterov@cwi.nl)"}

# %%
list_of_requested_entities_nl = []

# %%
additional_claims_nl = {}

for term, no_claims_list in no_claims_nl_request.items():
    
    params["ids"] = ""
    
    # for debugging
    
    print("term:",term,"|","entities:",len(no_claims_list))

# - CONDITIONS - #

    # if len of the list > 50 and there's a remainder
    if len(no_claims_list) > 50 and len(no_claims_list) % 50 > 0:
        loops = len(no_claims_list) // 50 + 1 # add another loop for requests
        
    # if len of the list > 50 and no remainder    
    if len(no_claims_list) > 50 and len(no_claims_list) % 50 == 0:
        loops = len(no_claims_list) // 50
        
    # otherwise loops = 1 (len < 50 or len = 50)    
    if len(no_claims_list) < 50:
        loops = 1
        
    # for debugging
    
    print("loops:",loops)
        
# - REQUEST LOOPS - #   
        
    # counters to slice list_of_entities
    start = 0 
    end = 0
    query_result_list = []
    
    for i in range(0,loops):
        ids_string = "" # putting Qs in one string
        end = end + 50

        for q in no_claims_list[start:end]:
            if q not in list_of_requested_entities_nl:
                ids_string = ids_string + f"{q}|"
                list_of_requested_entities_nl.append(q) # remebering requested entities to prevent duplicates

        start = start + 50

        # updating params

        params["ids"] = ids_string.rstrip("|")

        # sending a request
        d = requests.get(url,params=params,headers=headers)
        claims = d.json() # claims per request
        
        if 'entities' in claims:
            query_result_list.append(claims['entities']) # saving all claims
    
    # for debugging        
    print("actual_results:",len(query_result_list),[len(i) for i in query_result_list])

# - SAVING RESULTS - #
        
    additional_claims_nl[term] = query_result_list
# Out:
# term: homo | entities: 1
# loops: 1
# actual_results: 1 [1]
# term: koelies | entities: 1
# loops: 1
# actual_results: 1 [1]
# term: roma | entities: 2
# loops: 1
# actual_results: 1 [2]
# term: mumbai | entities: 1
# loops: 1
# actual_results: 1 [1]
# term: blank | entities: 1
# loops: 1
# actual_results: 1 [1]
# term: oriëntale | entities: 3
# loops: 1
# actual_results: 1 [3]
# term: historischer | entities: 37
# loops: 1
# actual_results: 1 [37]
# term: historisch | entities: 63
# loops: 2
# actual_results: 2 [35, 12]
# term: berber | entities: 1
# loops: 1
# actual_results: 1 [1]
# term: berbers | entities: 1
# loops: 1
# actual_results: 0 []
# term: blanks | entities: 1
# loops: 1
# actual_results: 0 []
# term: historische | entities: 100
# loops: 2
# actual_results: 2 [32, 40]
# term: oriëntaler | entities: 1
# loops: 1
# actual_results: 0 []
# term: wester | entities: 10
# loops: 1
# actual_results: 1 [9]
# term: trans | entities: 3
# loops: 1
# actual_results: 1 [3]
# term: "etnische groep" | entities: 1
# loops: 1
# actual_results: 1 [1]
# term: indo | entities: 2
# loops: 1
# actual_results: 1 [1]
# term: westers | entities: 10
# loops: 1
# actual_results: 0 []
# term: blanker | entities: 1
# loops: 1
# actual_results: 0 []

# %%
# merging additional claims with all the claims

with open('/Users/anesterov/claims_nl/merged_claims_nl.json', 'r') as jf:
    all_claims_nl = json.load(jf)

# %%
for term, claims in additional_claims_nl.items():
    if claims != []:
        all_claims_nl[term].extend(claims)

# %%
# rewriting the resulting file
with open('/Users/anesterov/claims_nl/merged_claims_nl.json', 'w') as output_file:
    json.dump(all_claims_nl, output_file)

# %% [markdown]
# ### Re-running Step 1 with new claims

# %% [markdown]
# #### EN

# %%
for list_of_entities in additional_claims['historic']:
    #print(list_of_entities)
    
    for e_id, values in list_of_entities.items():
        if 'claims' in values:
            for v in values['claims'].values():
                for l in v:
                    if 'datavalue' in l['mainsnak']:
                        if (l['mainsnak']['property'] == 'P31' or l['mainsnak']['property'] == 'P279') \
                        and l['mainsnak']['datavalue']['value']['id'] in to_exclude.keys():
                            entities_to_exlude.append(e_id)

# %%
len(entities_to_exlude)
# Out:
# 69036

# %%
# saving the list of entities that will be filtered out

with open("exclude_entities_en.txt","w") as txt_file:
    for i in entities_to_exlude:
        txt_file.writelines(f"{i},\n")

# %% [markdown]
# #### NL

# %%
for term, lists in additional_claims_nl.items():
    for i in lists:
        for e_id, claims in i.items():
            for v in claims['claims'].values():
                for l in v:
                    if 'datavalue' in l['mainsnak']:
                        if (l['mainsnak']['property'] == 'P31' or l['mainsnak']['property'] == 'P279') \
                        and l['mainsnak']['datavalue']['value']['id'] in to_exclude.keys():
                            entities_to_exclude_nl.append(e_id)

# %%
len(entities_to_exclude_nl)
# Out:
# 15886

# %%
# saving the list of entities that will be filtered out

with open("exclude_entities_nl.txt","w") as txt_file:
    for i in entities_to_exclude_nl:
        txt_file.writelines(f"{i},\n")

# %% [markdown]
# ## Saving the clean version
# #### Also excluding entities without entity terms

# %% [markdown]
# ### EN

# %%
filtered_results_en = {}
for key,value in wd_search_results_en.items():
    sub_dict = {}
    for k,v in value.items():
        if 'title' in v and 'entityterms' in v and v['title'] not in entities_to_exlude:
            sub_dict[k] = v
    filtered_results_en[key] = sub_dict

# %%
with open("/Users/anesterov/wd/wikidata_search_results_en_clean.json","w") as jf:
    json.dump(filtered_results_en, jf)

# %% [markdown]
# ### NL

# %%
exclude_all = entities_to_exlude + entities_to_exclude_nl

# %%
filtered_results_nl = {}
for key,value in wd_search_results_nl.items():
    sub_dict = {}
    for k,v in value.items():
        if 'title' in v and 'entityterms' in v and v['title'] not in exclude_all:
            sub_dict[k] = v
    filtered_results_nl[key] = sub_dict

# %%
with open("/Users/anesterov/wd/wikidata_search_results_nl_clean.json","w") as jf:
    json.dump(filtered_results_nl, jf)

# %% [markdown]
# ## Exclude entities: step 2
# * Excluding names: if the target word is used in a label with uppercase AND if an entity has the properties "family name" and "given name"

# %% [markdown]
# #### EN

# %%
# Literals:
# filtered_results_en
# filtered_results_nl

# Claims:
# all_claims – English
# all_claims_nl – Duth

# properties
# P735 – "given name"
# P734 – "family name"

# %%
names_en = []

for target_word, entityterms in filtered_results_en.items():

    # taking unigrams only
    # n-grams are put in "", and complex words have '-'
    if '"' not in target_word and '-' not in target_word:
        
        for page_id, values in entityterms.items():
            if 'label' in values['entityterms'] and \
            re.search(target_word.capitalize(),values['entityterms']['label'][0]) != None:
                names_en.append(values['title'])

# %%
# 70K entities have the capitalized target word in the label
len(names_en)
# Out:
# 70002

# %%
names_to_filter = []

for target_word, claims_lists in all_claims.items():
    for claims in claims_lists:
        for e_id in claims.keys():
            # if there are the properties "family name" or "given name"
            if e_id in names_en and ('P734' in claims[e_id]['claims'].keys() or \
                                     'P735' in claims[e_id]['claims'].keys()):
                names_to_filter.append(e_id)

# %%
# excluding the entities from the results

clean_en = {}
for target_word, entityterms in filtered_results_en.items():
    sub_dict = {}
    for page_id, values in entityterms.items():
        if values['title'] not in names_to_filter:
            sub_dict[page_id] = values
            
    clean_en[target_word] = sub_dict

# %%
# rewriting the clean file

with open("/Users/anesterov/wd/wikidata_search_results_en_clean.json","w") as jf:
    json.dump(clean_en, jf)

# %% [markdown]
# #### NL

# %%
names_nl = []

for target_word, entityterms in filtered_results_nl.items():

    # taking unigrams only
    # n-grams are put in "", and complex words have '-'
    if '"' not in target_word and '-' not in target_word:
        
        for page_id, values in entityterms.items():
            if 'label' in values['entityterms'] and \
            re.search(target_word.capitalize(),values['entityterms']['label'][0]) != None:
                names_nl.append(values['title'])

# %%
# NL entities with capitalized target terms
len(names_nl)
# Out:
# 13150

# %%
names_to_filter_nl = []

# checking both EN and NL claims

# English claims

for target_word, claims_lists in all_claims.items():
    for claims in claims_lists:
        for e_id in claims.keys():
            # if there are the properties "family name" or "given name"
            if e_id in names_nl and ('P734' in claims[e_id]['claims'].keys() or \
                                     'P735' in claims[e_id]['claims'].keys()):
                names_to_filter_nl.append(e_id)
                
# Dutch claims
                
for target_word, claims_lists in all_claims_nl.items():
    for claims in claims_lists:
        for e_id in claims.keys():
            # if there are the properties "family name" or "given name"
            if e_id in names_nl and ('P734' in claims[e_id]['claims'].keys() or \
                                     'P735' in claims[e_id]['claims'].keys()):
                names_to_filter_nl.append(e_id)

# %%
len(names_to_filter_nl)
# Out:
# 3365

# %%
# excluding the entities from the results

clean_nl = {}
for target_word, entityterms in filtered_results_nl.items():
    sub_dict = {}
    for page_id, values in entityterms.items():
        if values['title'] not in names_to_filter_nl:
            sub_dict[page_id] = values
            
    clean_nl[target_word] = sub_dict

# %%
# rewriting the clean file

with open("/Users/anesterov/wd/wikidata_search_results_nl_clean.json","w") as jf:
    json.dump(clean_nl, jf)
