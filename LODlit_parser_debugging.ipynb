# %% [markdown]
# ### lodlitparser

# %%
import json
import requests
import time
import re
import sys
from io import BytesIO
from zipfile import ZipFile
from SPARQLWrapper import SPARQLWrapper, JSON
# install NLTK, download wordnet31 ('https://github.com/nltk/nltk_data/blob/gh-pages/packages/corpora/wordnet31.zip');
# put the content of 'wordnet31' to 'wordnet' in 'nltk_data/corpora' (there are issues with importing wordnet31 from nltk.corpus)
from nltk.corpus import wordnet as wn
# download OpenDutchWordnet from 'https://github.com/cultural-ai/OpenDutchWordnet'

# %% [markdown]
# ### Wikidata

# %%
def wd(qids:list,lang:str,user_agent:str) -> dict:
    
    """
    Requesting labels, aliases, descriptions of Wikidata entities
    qids: list of entity IDs (str) (requests 50 entities at a time slicing the list)
    lang: str with language code; for example, 'en' or 'nl';
    (see language codes in Wikidata: https://www.wikidata.org/w/api.php?action=help&modules=wbgetentities)
    user_agent: str with user-agent's info; required by Wikidata (see: https://meta.wikimedia.org/wiki/User-Agent_policy)
    Returns a dict: {'QID': {'type': '',
                     'id': 'QID',
                     'labels': {'lang': {'language': 'lang', 'value': ''}},
                     'descriptions': {'lang': {'language': 'lang','value': ''}},
                     'aliases': {'lang': [{'language': 'lang', 'value': ''}
    """
    
    # 'wbgetentities' constant params
    url = "https://www.wikidata.org/w/api.php"
    params = {"action":"wbgetentities",
              "ids":"", # string of entities (max=50)
              "props":"labels|aliases|descriptions",
              "languages":lang,
              "format":"json"}
    headers = {"user-agent":user_agent}

    # - N LOOPS - #

    # if there's a remainder
    if len(qids) % 50 > 0:
        loops = len(qids) // 50 + 1 # add another loop for requests
    else:
        loops = len(qids) // 50

    # - REQUEST LOOPS - #   

    # counters to slice qids

    start_quid_str = 0
    end_quid_str = 0

    for i in range(0,loops):
        ids_string = "" # putting Qs in one string
        end_quid_str = end_quid_str + 50 # max 50 entities per request

        for q in qids[start_quid_str:end_quid_str]:
            ids_string = ids_string + f"{q}|"

        start_quid_str = start_quid_str + 50

        # updating params

        params["ids"] = ids_string.rstrip("|")

        # sending a request
        d = requests.get(url,params=params,headers=headers)
        literals = d.json() # claims per request

    return literals

# %% [markdown]
# ### AAT

# %%
def aat(aat_uri:list,lang:str) -> dict:
    '''
    Querying prefLabel, altLabel, scopeNote, rdfs comments of concepts in AAT;
    Sends SPARQL queries to the AAT endpoint via SPARQLwrapper 
    aat_uri: list of AAT concepts IDs (str) ['ID']
    lang: str 'en' or 'nl'
    Returns a dict with query results: {'ID':{'lang':'en',
                                              'prefLabel':'',
                                              'altLabels':[],
                                              'scopeNote':'',
                                              'prefLabel_comment':'',
                                              'altLabel_comment':''}
    '''
    
    sparql = SPARQLWrapper("http://vocab.getty.edu/sparql")
    
    if lang == 'en':
        lang_code = '300388277'
    if lang == 'nl':
        lang_code = '300388256'
        
    result_dict = {}
        
    for uri in aat_uri:
        
        result_dict[uri] = {}
        
        query_string = '''SELECT ?prefLabel (GROUP_CONCAT(?altLabel;SEPARATOR="#") AS ?altLabels)
        # ?scopeNote ?prefLabel_comment ?altLabel_comment
        WHERE {aat:''' + uri + ''' xl:prefLabel ?pL .?pL dcterms:language aat:''' + lang_code + ''';
        xl:literalForm ?prefLabel .
        OPTIONAL {?pL rdfs:comment ?prefLabel_comment . }
        OPTIONAL {aat:''' + uri + ''' xl:altLabel ?aL .
        # ?aL dcterms:language aat:''' + lang_code + ''';
        xl:literalForm ?altLabel . 
        OPTIONAL { ?aL rdfs:comment ?altLabel_comment . }}
        OPTIONAL {aat:''' + uri + ''' skos:scopeNote / dcterms:language aat:'''+ lang_code + ''';
        skos:scopeNote / rdf:value ?scopeNote . }}
        GROUP BY ?prefLabel ?scopeNote ?prefLabel_comment ?altLabel_comment'''
        
        sparql.setQuery(query_string)
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
        
        altLabels = []
        scopeNote = None
        prefLabel_comment = None
        altLabel_comment = None
        
        for result in results['results']['bindings']:
            
            if 'altLabels' in result:
                altLabels = result['altLabels']['value'].split('#')
            if 'scopeNote' in result:
                scopeNote = result['scopeNote']['value']
            if 'prefLabel_comment' in result:
                prefLabel_comment = result['prefLabel_comment']['value']
            if 'altLabel_comment' in result:
                altLabel_comment = result['altLabel_comment']['value']

            result_dict[uri]['lang'] = lang
            result_dict[uri]['prefLabel'] = result['prefLabel']['value']
            result_dict[uri]['altLabels'] = altLabels
            result_dict[uri]['prefLabel_comment'] = prefLabel_comment
            result_dict[uri]['altLabel_comment'] = altLabel_comment
            result_dict[uri]['scopeNote'] = scopeNote
    print(query_string)    
    return result_dict

# %% [markdown]
# ### NMVW

# %%
def nmvw(term_ids:list) -> dict:
    '''
    Getting info about terms by their handle IDs in NMVW-thesaurus
    term_ids: list of term IDs (str)
    Returns a dict with query results: {'ID': {'prefLabel': '',
                                               'altLabel': [],
                                               'notes': [],
                                               'exactMatch': '',
                                               'scheme': ''}}
    '''
    
    # nmvw: importing thesaurus
    path_to_nmvw = 'https://github.com/cultural-ai/wordsmatter/raw/main/NMVW/nmvw_thesaurus.json.zip'
    nmvw_raw = requests.get(path_to_nmvw).content
    nmvw_zip = ZipFile(BytesIO(nmvw_raw))
    nmvw_json = json.loads(nmvw_zip.read(nmvw_zip.infolist()[0]).decode())

    results_nmvw = {}
    
    for term_id in term_ids:
        handle = 'https://hdl.handle.net/20.500.11840/termmaster' + term_id
        results_nmvw[handle] = nmvw_json.get(handle)
        
    return results_nmvw

# %% [markdown]
# ### Princeton WordNet

# %%
def pwn(synsets:list) -> dict:
    '''
    Getting lemmata, definition, examples of a synset
    synsets: a list of synsets IDs (str)
    Return a dict: {'synset_id': {'lemmata': '',
                                   'definition': '',
                                   'examples': []}
    Requires NLTK, wordnet corpus version 3.1
    '''
    
    results_pwn = {}
    
    for s in synsets:
        synset = wn.synset(s)
        lemmata = [l.name() for l in synset.lemmas()]
        definition = synset.definition()
        examples = synset.examples()
        
        # writing results 
        results_pwn[s] = {'lemmata': lemmata,
                         'definition': definition,
                         'examples': examples}
        
    return results_pwn

# %% [markdown]
# ### ODWN

# %%
def odwn(le_ids:list, path_odwn:str) -> dict:
    '''
    Getting Lemma, sense definitions, examples, synset ID, synset definitions of ODWN Lexical Entries
    le_ids: list of Lexical Entries IDs (str)
    path_odwn: str path to the directory with OpenDutchWordnet (not including the module itself, for example 'user/Downloads')
    Returns a dict: {'le_id': {'lemma': '',
                                'sense_def': '',
                                'examples': [],
                                'synset_ID': '',
                                'synset_def': []}
    '''
    # importing ODWN
    sys.path.insert(0,path_odwn)
    from OpenDutchWordnet import Wn_grid_parser
    # creating an instance
    instance = Wn_grid_parser(Wn_grid_parser.odwn)
    
    # importing all synset definitions
    path_to_glosses = "https://raw.githubusercontent.com/cultural-ai/wordsmatter/main/ODWN/odwn_synset_glosses.json"
    synset_glosses = requests.get(path_to_glosses).json()
    
    results_odwn = {}

    for le_id in le_ids:
        le = instance.les_find_le(le_id)
        synset_id = le.get_synset_id()

        sense_def = le.get_definition()
        if sense_def == '':
            sense_def = None

        results_odwn[le_id] = {'lemma': le.get_lemma(),
                                'sense_def': sense_def,
                                'examples': le.get_sense_example(),
                                'synset_ID': synset_id,
                                'synset_def': synset_glosses.get(synset_id)}
    return results_odwn

# %% [markdown]
# #### check where a query term is found per resource:
# * Wikidata: labels, aliases
# * AAT: prefLabel, altLabel
# * NMVW: prefLabel, altLabel
# * Princeton WordNet: no checking, only lemmata
# * ODWN: no checking, only lemma

# %% [markdown]
# #### Getting properties where cont terms are used

# %%
def get_literals(resource:str) -> str:
    '''
    Getting literal values of related matches
    resource: str name of the resource 'aat', 'wikidata', 'pwn', 'odwn', 'nmvw' 
    path_odwn: str path to the directory with OpenDutchWordnet (not including the module itself, for example 'user/Downloads')
    Saves json files with literal values:
    aat: 'aat_rm_en.json','aat_rm_nl.json'
    wikidata: 'wikidata_rm_en.json','wikidata_rm_nl.json'
    pwn: 'pwn_rm.json'
    odwn: 'odwn_rm.json'
    nmvw: 'nmvw_rm.json'
    
    '''
    
    # importing related matches
    path_to_rm = 'https://github.com/cultural-ai/wordsmatter/raw/main/rm.json'
    related_matches = requests.get(path_to_rm).json()

    if resource == 'aat':
        # AAT in EN
        aat_en = [v['related_matches']['aat'][0] for v in related_matches.values() if v['lang'] == 'en' \
                  and 'None' not in v['related_matches']['aat']]
        aat_en_results = aat(aat_en,'en')
        with open('aat_rm_en.json', 'w') as jf:
            json.dump(aat_en_results, jf)
        print("AAT EN is saved")

        # AAT in NL
        aat_nl = [v['related_matches']['aat'][0] for v in related_matches.values() if v['lang'] == 'nl' \
                  and 'None' not in v['related_matches']['aat']]
        aat_nl_results = aat(aat_nl,'nl')
        with open('aat_rm_nl.json', 'w') as jf:
            json.dump(aat_nl_results, jf)
        print("AAT NL is saved")
    
    if resource == 'wikidata':
        user_agent = input("Enter your user agent details for Wikidata:")
        
        # Wikidata in EN
        wikidata_en = [v['related_matches']['wikidata'][0] for v in related_matches.values() if v['lang'] == 'en' \
                  and 'None' not in v['related_matches']['wikidata']]
        wikidata_en_results = wd(wikidata_en,'en',user_agent)
        with open('wikidata_rm_en.json', 'w') as jf:
            json.dump(wikidata_en_results, jf)
        print("Wikidata EN is saved")

        # Wikidata in NL
        wikidata_nl = [v['related_matches']['wikidata'][0] for v in related_matches.values() if v['lang'] == 'nl' \
                  and 'None' not in v['related_matches']['wikidata']]
        wikidata_nl_results = wd(wikidata_nl,'nl',user_agent)
        with open('wikidata_rm_nl.json', 'w') as jf:
            json.dump(wikidata_nl_results, jf)
        print("Wikidata NL is saved")
        
    if resource == 'pwn':
        # PWN
        pwn_synsets = []

        for v in related_matches.values():
            if v['lang'] == 'en' and 'None' not in v['related_matches']['pwn']:
                pwn_synsets.extend(v['related_matches']['pwn'])

        pwn_results = pwn(pwn_synsets)
        with open('pwn_rm.json', 'w') as jf:
            json.dump(pwn_results, jf)
        print("PWN is saved")
        
    if resource == 'odwn':
        path_odwn = input("Path to your local OpenDutchWordNet directory:")
        #6 ODWN
        odwn_synsets = []

        for v in related_matches.values():
            if v['lang'] == 'nl' and 'None' not in v['related_matches']['odwn']:
                odwn_synsets.extend(v['related_matches']['odwn'])

        odwn_results = odwn(odwn_synsets,path_odwn)
        with open('odwn_rm.json', 'w') as jf:
            json.dump(odwn_results, jf)
        print("ODWN is saved")
        
    if resource == 'nmvw':
        #7 NMVW
        nmvw_handles = [v['related_matches']['nmvw'][0] for v in related_matches.values() if v['lang'] == 'nl' \
                  and 'None' not in v['related_matches']['nmvw']]
        nmvw_results = nmvw(nmvw_handles)
        with open('nmvw_rm.json', 'w') as jf:
            json.dump(nmvw_results, jf)
        print("NMVW is saved")
    
    return ("All files are saved")

# %%
#### Identifying properties where cont terms appear

# %%
def get_hits() -> dict:
    '''
    Adding the info about where contentious terms were found to the related matches
    (applicable to the query results from AAT, Wikidata, and NMVW)
    source: str with the path to the json file with related matches 'related_matches.json'
    '''

# %%
# importing related matches
with open('/Users/anesterov/reps/wordsmatter/rm.json','r') as jf:
    related_matches = json.load(jf)

# %%
# Testing functions

# %%
from LODlitParser import wd

# %%
user_agent = "bot testing search"

# %%
filter_by_keywords = ['scientific','article']

# %%
filter_by_statements = [('P31','Q5'),('P279','Q7187')]

# %%
wd.get_search_hits("aboriginal","en",user_agent,[],statements)
# Out:
# {'aboriginal': 7354}

# %%
test_search_results = wd.get_lit_by_term("headhunter","en",user_agent)

# %%
params = ''

# %%
# filtering by keywords
if filter_by_keywords != []:
    keyword_str = ''
    for kw in filter_by_keywords:
        keyword_str = keyword_str + f" -{kw}"
    params = params + keyword_str

# filtering by statements    
if filter_by_statements != []:
    statements_str = ''
    for t in filter_by_statements:
        statements_str = statements_str + f" -haswbstatement:{t[0]}={t[1]}"
    params = params + statements_str

# %%
params
# Out:
# ' -scientific -article -haswbstatement:P31=Q5 -haswbstatement:P279=Q7187'

# %%
wd.get_lit_by_q(['Q363389'],"nl",user_agent)
# Out:
# [{'Q363389': {'type': 'item',
#    'id': 'Q363389',
#    'labels': {'nl': {'language': 'nl', 'value': 'Adolf Meyer-Abich'}},
#    'descriptions': {'nl': {'language': 'nl',
#      'value': 'Duits bibliothecaris (1893-1971)'}},
#    'aliases': {}}}]

# %%
qids = ['Q363389','Q18530542','Q41710']

# %%
langs = ['en','nl']

# %%
props = ['P31','P279','P1552']

# %%
path = "/Users/anesterov/wd/testing/"

# %%
wd.get_labels_by_q(qids,langs,user_agent)
# Out:
# en|nl
# {'entities': {'Q363389': {'type': 'item', 'id': 'Q363389', 'labels': {'en': {'language': 'en', 'value': 'Adolf Meyer-Abich'}, 'nl': {'language': 'nl', 'value': 'Adolf Meyer-Abich'}}}, 'Q18530542': {'type': 'item', 'id': 'Q18530542', 'labels': {'en': {'language': 'en', 'value': 'Orde Jonathan Wingate'}}}}, 'success': 1}
# {'en': 'Adolf Meyer-Abich', 'nl': 'Adolf Meyer-Abich'}
# {'en': 'Orde Jonathan Wingate'}
# {'labels': {'Q363389': {'en': 'Adolf Meyer-Abich', 'nl': 'Adolf Meyer-Abich'},
#   'Q18530542': {'en': 'Orde Jonathan Wingate'}},
#  'failed': []}

# %%
wd.get_claims(qids,props,user_agent,path)
# Out:
# 'Requests are saved in /Users/anesterov/wd/testing/'

# %%
wd.find_where_query_term_appears(test_search_results,'en')
# Out:
# {'headhunter': [{'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q105877016',
#    'prefLabel': 'Who Says Yes When the Headhunter Calls? Understanding Executive Job Search Behavior',
#    'aliases': None,
#    'description': ['scientific article published in August 2013'],
#    'index': 38,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q114485638',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['episode of Quincy, M.E. (S6 E10)'],
#    'index': 14,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q114498379',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['episode of Police Story (S2 E13)'],
#    'index': 10,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q114521710',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['episode of Kingdom (S3 E4)'],
#    'index': 11,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q12315869',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['2009 film by Rumle Hammerich'],
#    'index': 28,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q15814542',
#    'prefLabel': 'Headhunter Blitz',
#    'aliases': None,
#    'description': ['album by Krokus'],
#    'index': 52,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q16621279',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['1989 film directed by Francis Schaeffer'],
#    'index': 59,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q18530542',
#    'prefLabel': 'Orde Jonathan Wingate',
#    'aliases': None,
#    'description': 'army officer, stock broker and headhunter, only child of Orde Charles Wingate (1944-2000)',
#    'index': 33,
#    'found_in': 'description'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q290088',
#    'prefLabel': 'gunner',
#    'aliases': ['shooter', 'headhunter', 'kamikaze'],
#    'description': ['specialist position in American football special teams, who runs down the sideline very quickly in an attempt to tackle the kick or punt returner'],
#    'index': 34,
#    'found_in': 'aliases'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q3128987',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['1983 studio album by the Swiss hard rock band Krokus'],
#    'index': 9,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q3128995',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['2001 video game developed by Amuze'],
#    'index': 4,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q324798',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['German metal band'],
#    'index': 7,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q3421786',
#    'prefLabel': 'Rebirth',
#    'aliases': None,
#    'description': '1994 studio album by Headhunter',
#    'index': 43,
#    'found_in': 'description'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q343302',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['Wikimedia disambiguation page'],
#    'index': 19,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q3987154',
#    'prefLabel': 'The Funky Headhunter',
#    'aliases': None,
#    'description': ['album by MC Hammer'],
#    'index': 12,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q4023335',
#    'prefLabel': 'Z-95 Headhunter',
#    'aliases': None,
#    'description': ['fictional spacecraft in the Star Wars universe'],
#    'index': 21,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q4040469',
#    'prefLabel': 'Headhunter',
#    'aliases': ['hh.ru',
#     'HeadHunter Company',
#     'HeadHunter Group Ltd.',
#     'Khedkhanter OOO',
#     'HeadHunter Group PLC'],
#    'description': ['Russian Internet recruitment company'],
#    'index': 5,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q4040469',
#    'prefLabel': 'Headhunter',
#    'aliases': ['hh.ru',
#     'HeadHunter Company',
#     'HeadHunter Group Ltd.',
#     'Khedkhanter OOO',
#     'HeadHunter Group PLC'],
#    'description': ['Russian Internet recruitment company'],
#    'index': 5,
#    'found_in': 'aliases'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q4040469',
#    'prefLabel': 'Headhunter',
#    'aliases': ['hh.ru',
#     'HeadHunter Company',
#     'HeadHunter Group Ltd.',
#     'Khedkhanter OOO',
#     'HeadHunter Group PLC'],
#    'description': ['Russian Internet recruitment company'],
#    'index': 5,
#    'found_in': 'aliases'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q4040469',
#    'prefLabel': 'Headhunter',
#    'aliases': ['hh.ru',
#     'HeadHunter Company',
#     'HeadHunter Group Ltd.',
#     'Khedkhanter OOO',
#     'HeadHunter Group PLC'],
#    'description': ['Russian Internet recruitment company'],
#    'index': 5,
#    'found_in': 'aliases'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q4140607',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['2005 film'],
#    'index': 31,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q48442351',
#    'prefLabel': '\'Murder by milligrams\': enhancement technologies and therapeutic zeal in Timothy Findley\'s Headhunter".',
#    'aliases': None,
#    'description': ['scientific article published in September 2012'],
#    'index': 47,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719587',
#    'prefLabel': 'Set 1. No.7: from the "Headhunter Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 22,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719613',
#    'prefLabel': 'Set 1. No. 3: from the "Headhunter Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 20,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719630',
#    'prefLabel': 'Set 1. No. 6: from the "Headhunter Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 23,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719650',
#    'prefLabel': 'Set 1. No. 1: from the "Headhunter [sic] Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 32,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719667',
#    'prefLabel': 'Set 1. No. 2: from the "Headhunter Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 26,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719724',
#    'prefLabel': 'Set 1. No. 5: from the "Headhunter Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 27,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719747',
#    'prefLabel': 'Set 1. No. 4: from the "Headhunter Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 17,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q50719763',
#    'prefLabel': 'Set 1. No. 8: from the "Headhunter Set"',
#    'aliases': None,
#    'description': ['painting by Thomas Nandjiwarra amagula'],
#    'index': 24,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q52288371',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['episode of Adderly (S2 E9)'],
#    'index': 15,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5249454',
#    'prefLabel': 'Declaration of a Headhunter',
#    'aliases': None,
#    'description': ['album by Stuck Mojo'],
#    'index': 13,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5354995',
#    'prefLabel': 'Electoral Headhunter',
#    'aliases': None,
#    'description': None,
#    'index': 51,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q54201500',
#    'prefLabel': 'Knotting of an 8-French "headhunter" catheter and its successful removal.',
#    'aliases': None,
#    'description': ['scientific article'],
#    'index': 8,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q54736522',
#    'prefLabel': 'Knot formation: a frequent complication of 7-French "headhunter" catheters.',
#    'aliases': None,
#    'description': ['scientific article'],
#    'index': 16,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5689592',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['1993 novel by Timothy Findley'],
#    'index': 44,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5689593',
#    'prefLabel': 'Headhunter',
#    'aliases': None,
#    'description': ['1988 song by the Belgian EBM band Front 242'],
#    'index': 18,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5689598',
#    'prefLabel': 'Headhunter Redemption',
#    'aliases': ['Headhunter: Redemption', 'Headhunter 2'],
#    'description': ['2003 video game'],
#    'index': 6,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5689598',
#    'prefLabel': 'Headhunter Redemption',
#    'aliases': ['Headhunter: Redemption', 'Headhunter 2'],
#    'description': ['2003 video game'],
#    'index': 6,
#    'found_in': 'aliases'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5689598',
#    'prefLabel': 'Headhunter Redemption',
#    'aliases': ['Headhunter: Redemption', 'Headhunter 2'],
#    'description': ['2003 video game'],
#    'index': 6,
#    'found_in': 'aliases'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q5689600',
#    'prefLabel': 'Headhunter Records',
#    'aliases': None,
#    'description': ['American rock music record label'],
#    'index': 3,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q58000602',
#    'prefLabel': 'Decapitation of the tortoise Chersina angulata: is the large grey mongoose a headhunter?',
#    'aliases': None,
#    'description': ['journal article; published in African Zoology in 2002'],
#    'index': 42,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q64618528',
#    'prefLabel': 'The Headhunter and His Family',
#    'aliases': None,
#    'description': ['drawing in the National Gallery of Art (NGA 140356)'],
#    'index': 40,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q66805206',
#    'prefLabel': 'A headhunter and his wife, Rubiana Lagoon',
#    'aliases': None,
#    'description': ['artwork by A. W. Dobbie , created during 1899, located in the Art Gallery of South Australia'],
#    'index': 35,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q66927574',
#    'prefLabel': 'Removal of figure-8 knot in femoral-cerebral "headhunter IV" catheter during angiography',
#    'aliases': None,
#    'description': ['scientific article published on 01 May 1975'],
#    'index': 37,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q67560584',
#    'prefLabel': 'A method of removal of knotted Headhunter catheter',
#    'aliases': None,
#    'description': ['scientific article published on 01 March 1977'],
#    'index': 25,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q6902629',
#    'prefLabel': 'Monsopiad',
#    'aliases': None,
#    'description': 'Malaysian headhunter',
#    'index': 55,
#    'found_in': 'description'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q70875186',
#    'prefLabel': 'How to use a headhunter',
#    'aliases': None,
#    'description': ['scientific article published on 01 July 1984'],
#    'index': 46,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q71128441',
#    'prefLabel': 'Intra-arterial hepatic infusion via the axillary artery using the headhunter catheter',
#    'aliases': None,
#    'description': ['scientific article published on 01 January 1980'],
#    'index': 53,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q73115140',
#    'prefLabel': "What recruiters won't tell you. Job seekers should limnit their expectations when working with a headhunter",
#    'aliases': None,
#    'description': ['scientific article published on 01 January 2003'],
#    'index': 39,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q77635137',
#    'prefLabel': 'Hunting for a headhunter. How to select a physician search firm',
#    'aliases': None,
#    'description': ['scientific article published on 01 May 1989'],
#    'index': 49,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q77670789',
#    'prefLabel': 'Advice from a headhunter',
#    'aliases': None,
#    'description': ['scientific article published on 01 July 1989'],
#    'index': 57,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q78980641',
#    'prefLabel': 'Headhunter : rikstäckande tidning för rekrytering och ledarskap',
#    'aliases': None,
#    'description': ['Swedish periodical'],
#    'index': 50,
#    'found_in': 'prefLabel'},
#   {'query_term': 'headhunter',
#    'lang': 'en',
#    'QID': 'Q97933272',
#    'prefLabel': 'The Headhunter Demos',
#    'aliases': None,
#    'description': ['2000 EP by The Clay People'],
#    'index': 58,
#    'found_in': 'prefLabel'}]}

# %%
data_path = "/Users/anesterov/wd/29sep/results_w_claims_en.json"
save_path = "/Users/anesterov/wd/jan/"

# %%
wd.filter_proper_names(data_path, "en", save_path)
# Out:
# Q109939822 V. de Schouten de Batavia
# Q112463576 Mitch Batavia
# Q31941779 Andrew Batavia
# Q47163413 Monique Batavia
# Q90123715 Chelsea Batavia
# Q90628351 Aashil A Batavia
# Q90628351 Aashil A Batavia
# Q90734418 Jason P Van Batavia
# Q102110885 Neal Madras
# Q105972402 Madras A.Kannan
# Q27804537 Giridhar Madras
# Q38006024 Monika Madras
# Q43159749 Giridhar Madras
# Q61100109 Neal Madras
# Q76123026 Sarah Moor
# Q76131692 Anne Moor
# Q76141442 Thomas Moor
# Q76218994 John Bernard Moor
# Q76289828 Katherine Maria Moor
# Q7668524 T. Moor
# Q87917322 Dominik Moor
# Q90252789 Manuela Moor
# Q91637383 Vicky Jocelyne Moor Ama
# Q91896507 Avigail Moor
# Q92110232 Liz Moor
# Q92967775 Sarah R Moor
# Q92967775 Sarah R Moor
# Q96198599 John Moor
# Q96989191 Andries de Moor
# Q97569180 Sybil Moor
# Q97598124 Delphine De Moor
# Q97681614 Célia Moor
# Q100886594 Aalim Moor
# Q108329710 Louis Moor
# Q112371068 Lise Moor
# Q112448099 James Moor
# Q112547877 Karel Moor
# Q23641969 Karin Moor
# Q27940640 Jüri Moor
# Q85100452 Walter Hermann Moor
# Q95894938 Henne Moor
# Q110640686 Johanna de Moor
# Q112016973 Beila Moor
# Q112524366 A. P. G. de Moor
# Q2029252 Frank De Moor
# Q21455499 Alice Moor West
# Q2326440 Annie de Moor-Ringnalda
# Q27915244 Keith Moor
# Q27940642 Jüri Moor
# Q33138782 Arnaud Moor
# Q49996315 John De Moor
# Q54109220 Frederick Robert Moor
# Q54109220 Frederick Robert Moor
# Q109037546 Joseph De Moor
# Q113785641 Geertruida de Moor
# Q16732807 Ahmed Moor
# Q18211184 Philip Moor
# Q18211184 Philip Moor
# Q18637757 Peter Moor
# Q18637757 Peter Moor
# Q34611329 Andrea Moor
# Q4080697 Marianne Moor
# Q41556840 Jaap de Moor
# Q51917060 Jan De Moor
# Q6075624 Pieter de Moor
# Q6522746 Emmy Moor
# Q94507298 Ashlea Moor
# Q95268549 Alfons Moor
# Q96991381 Rudy De Moor
# Q112016975 Meier Moor
# Q113805755 Ed de Moor
# Q113805755 Ed de Moor
# Q11727825 Johannes Moor
# Q21935654 Jacques De Moor
# Q27831090 Paul Moor
# Q47122872 Moor
# Q55618453 Karl Moor
# Q6149543 Jan Moor-Jankowski
# Q62024382 Anthony Moor
# Q63197878 John William Moor
# Q94737869 Julia Moor
# Q95197368 Svenja Moor
# Q100886595 Jules Moor
# Q100886596 Jules Moor
# Q100886597 Julius Moor
# Q104772889 Louis Moor
# Q104772889 Louis Moor
# Q107996187 Ashleigh Marie  Moor
# Q108052751 Buddy Moor
# Q110846566 Ewout de Moor
# Q111832554 Kris Moor
# Q112135585 Justus Moor
# Q112430340 Johannes C. de Moor
# Q112434948 Julia Moor
# Q112496400 A. J. C. de Moor-van Vugt
# Q112762844 Nicole de Moor
# Q1520153 Max Moor
# Q16563410 Johannes Moor
# Q17517243 Tony Moor
# Q17517243 Tony Moor
# Q5237673 David Moor
# Q5725975 Henry Moor
# Q95660559 Beatrice Marxer-Moor
# Q104814417 Ned Moor
# Q104814417 Ned Moor
# Q12359525 Argo Moor
# Q16403902 Erich Osvald Moor
# Q20735085 Nordin De Moor
# Q4886182 Ben Moor
# Q63873477 William Moor-Znamensky
# Q63873477 William Moor-Znamensky
# Q63873477 William Moor-Znamensky
# Q71976693 Lara de Moor
# Q78066921 Caspar Moor
# Q81314570 Cornelius De Moor
White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q4934363 Robert S. White
# Q507664 Jesse White
# Q512025 Charlie White
# Q512025 Charlie White
# Q512025 Charlie White
# Q51424813 Peter D. White
# Q51424813 Peter D. White
# Q51779352 Lawrence M White
# Q51779352 Lawrence M White
# Q53970801 Martin White
# Q56073471 Thomas A White
# Q56073471 Thomas A White
# Q56491390 Andrew J. White
# Q56491390 Andrew J. White
# Q56491390 Andrew J. White
# Q56491390 Andrew J. White
# Q56555892 Richard L. White
# Q56555892 Richard L. White
# Q56555892 Richard L. White
# Q56555892 Richard L. White
# Q56555892 Richard L. White
# Q56555892 Richard L. White
# Q56555892 Richard L. White
# Q56555892 Richard L. White
# Q56670396 Michael T White
# Q56670396 Michael T White
# Q56991071 Connie White-Williams
# Q57016523 Michael White
# Q57016523 Michael White
# Q57135006 Kathryn White
# Q57156816 Jonathan M White
# Q57156816 Jonathan M White
# Q57292714 Christopher J White
# Q57292714 Christopher J White
# Q57414949 Joanne C. White
# Q57414949 Joanne C. White
# Q57848024 Nicky White
# Q58150224 Rob White
# Q58150224 Rob White
# Q58150224 Rob White
# Q586756 James White
# Q59185917 Robert N White
# Q59185917 Robert N White
# Q59218061 Katherine M White
# Q59218061 Katherine M White
# Q60527383 Craig R White
# Q60527383 Craig R White
# Q60633506 Martin John White
# Q60638965 Charles L White
# Q60638965 Charles L White
# Q60638965 Charles L White
# Q61988804 Lisa J White
# Q61988804 Lisa J White
# Q63381435 Ian R White
# Q63381435 Ian R White
# Q685291 Cyril Tenison White
# Q685291 Cyril Tenison White
# Q712996 Minor White
# Q712996 Minor White
# Q73031436 Susan White
# Q74409009 Sebastian Nicolas White
# Q772840 Gilbert White
# Q772840 Gilbert White
# Q87758891 M Christina White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q89098164 Andrew J. P. White
# Q942472 Clarence Hudson White
# Q942472 Clarence Hudson White
# Q942472 Clarence Hudson White
# Q942472 Clarence Hudson White
# Q958904 Byron White
# Q958904 Byron White
# Q97607903 Andrew Paul White
# Q101149310 Tim O White
# Q101149310 Tim O White
# Q102078460 Jacob Keaton White
# Q110680649 Art F. White
# Q113361431 Pamela J. White
# Q113361431 Pamela J. White
# Q1161219 Daniel White
# Q1378351 Mike White
# Q1378351 Mike White
# Q1387000 John White
# Q1387000 John White
# Q15455627 Merrill G. White
# Q1586301 Harrison White
# Q1586301 Harrison White
# Q1587897 Harvey D. White
# Q1587897 Harvey D. White
# Q1587897 Harvey D. White
# Q1594833 Oscar White Muscarella
# Q17146408 Ethelbert White
# Q1750714 Sylvain White
# Q1762270 Brian J. White
# Q1762270 Brian J. White
# Q1818166 Lenny White
# Q1864740 William White Howells
# Q19662178 Paul White
# Q21070058 Edward J. White
# Q21070058 Edward J. White
# Q21070058 Edward J. White
# Q2110122 Alice White
# Q2134201 Raymond M. White
# Q2134201 Raymond M. White
# Q2134201 Raymond M. White
# Q2253352 David A. R. White
# Q2253352 David A. R. White
# Q23767067 William White
# Q24138629 John White
# Q24138629 John White
# Q2623867 Alex White
# Q2641365 Alex Hyde-White
# Q2641538 Alex White
# Q2641538 Alex White
# Q269802 Julie White
# Q274080 Chrissie White
# Q28036915 Aprilfawn White
# Q288656 Shaun White
# Q288656 Shaun White
# Q292290 Ellen G. White
# Q292290 Ellen G. White
# Q30122901 Ryan White
# Q30323508 Lisa McElwee-White
# Q3047406 Joseph Blanco White
# Q3157339 Jack White
# Q3161128 James H. White
# Q3161128 James H. White
# Q3311742 Andrew White
# Q3311742 Andrew White
# Q3315564 Minor White
# Q3328866 Ruth White
# Q3328866 Ruth White
# Q337696 Matthew White Ridley, 1st Viscount Ridley
# Q3441473 Ron White
# Q3441473 Ron White
# Q34755762 Joseph White
# Q3517052 Ted White
# Q358306 Jaleel White
# Q358306 Jaleel White
# Q361617 E. B. White
# Q361617 E. B. White
# Q361617 E. B. White
# Q361617 E. B. White
# Q3760672 George White
# Q38804225 James White
# Q39187956 Rosemary G White
# Q39187956 Rosemary G White
# Q39779158 Sarah J White
# Q39779158 Sarah J White
# Q41048999 John A White
# Q41048999 John A White
# Q41429213 David White
# Q41739208 Bethany White
# Q41799743 Eugene White
# Q42236090 Brad J White
# Q42236090 Brad J White
# Q42326898 Jacinta F White
# Q42326898 Jacinta F White
# Q42396540 Lisa J. White
# Q42396540 Lisa J. White
# Q42412113 Douglas W White
# Q42412113 Douglas W White
# Q42790076 Melanie D White
# Q42790076 Melanie D White
# Q42945521 Nicholas G White
# Q42945521 Nicholas G White
# Q43240863 John R White
# Q43240863 John R White
# Q43240863 John R White
# Q43368162 John R White
# Q43368162 John R White
# Q43373154 Stephen J White
# Q43373154 Stephen J White
# Q43761882 Roberta F White
# Q43761882 Roberta F White
# Q43761882 Roberta F White
# Q4454539 Matthew E. White
# Q450815 Snowy White
# Q450815 Snowy White
# Q450815 Snowy White
# Q47503369 Helen White-Cooper
# Q49071049 David M. White
# Q49071049 David M. White
# Q49071049 David M. White
# Q504489 Andrew Dickson White
# Q504489 Andrew Dickson White
# Q504489 Andrew Dickson White
# Q504489 Andrew Dickson White
# Q504489 Andrew Dickson White
# Q5083521 Charles Wilbert White
# Q5083521 Charles Wilbert White
# Q5083521 Charles Wilbert White
# Q5083521 Charles Wilbert White
# Q5083521 Charles Wilbert White
# Q5083521 Charles Wilbert White
# Q51095003 Thomas P White
# Q51095003 Thomas P White
# Q5246547 Dean White
# Q52810630 Alan White
# Q534234 Persia White
# Q534234 Persia White
# Q53522699 Michael G. White
# Q53522699 Michael G. White
# Q535967 David White
# Q5395638 Errol White
# Q5395638 Errol White
# Q542180 Henry III the White
# Q549293 Simon White
# Q549293 Simon White
# Q549293 Simon White
# Q549293 Simon White
# Q55193702 Mark A. White
# Q55193702 Mark A. White
# Q56065957 Justin S White
# Q56065957 Justin S White
# Q56423811 Scott A White
# Q56423811 Scott A White
# Q56876923 Herman Brenner White
# Q56876923 Herman Brenner White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q56963021 Duanne A. White
# Q57014863 Jonathan White
# Q57042423 Iain White
# Q57074702 Claire E White
# Q57074702 Claire E White
# Q57085537 Roger White
# Q572735 Stanford White
# Q572735 Stanford White
# Q57564649 Ben P White
# Q57564649 Ben P White
# Q57564649 Ben P White
# Q57616560 Isabel White
# Q57638230 Stephanie A White
# Q57638230 Stephanie A White
# Q57638230 Stephanie A White
# Q57699411 Sarah White
# Q57891777 Scott M. White
# Q57891777 Scott M. White
# Q57896968 Ross G White
# Q57896968 Ross G White
# Q57969821 Tonya White
# Q580411 Matt White
# Q58323558 Simon R White
# Q58323558 Simon R White
# Q1422010 Orra White Hitchcock
# Q1422010 Orra White Hitchcock
# Q14472966 Michael White
# Q14472966 Michael White
# Q14472966 Michael White
# Q15487346 Henry Luke White
# Q15487346 Henry Luke White
# Q15487346 Henry Luke White
# Q15487346 Henry Luke White
# Q15487346 Henry Luke White
# Q15487346 Henry Luke White
# Q16224052 Angela White
# Q16224052 Angela White
# Q1634433 Hugh Lawson White
# Q1805943 Lari White
# Q1805943 Lari White
# Q1929810 Michael White
# Q1929810 Michael White
# Q19364767 Donald White
# Q2046038 Pae White
# Q2115403 Charles Daniel White
# Q216726 Ed White
# Q216726 Ed White
# Q216726 Ed White
# Q216726 Ed White
# Q216726 Ed White
# Q21823223 Brian Cabell White
# Q21823223 Brian Cabell White
# Q22086580 Raymond White Skolfield
# Q233131 Tarra White
# Q24288434 William Hedges-White, 3rd Earl of Bantry
# Q24389 Edward Douglass White
# Q24389 Edward Douglass White
# Q24389 Edward Douglass White
# Q24389 Edward Douglass White
# Q25184150 Susanna White
# Q25558510 Noni White
# Q264420 Chris White
# Q264420 Chris White
# Q264420 Chris White
# Q26819146 William Johnstone White
# Q26848 Leon Allen White
# Q26848 Leon Allen White
# Q27924675 Minnie White
# Q27924675 Minnie White
# Q27924675 Minnie White
# Q27924675 Minnie White
# Q28824148 Larry White
# Q28824148 Larry White
# Q3133152 Henry White
# Q3280725 Eg White
# Q3280725 Eg White
# Q328102 Matthew White Ridley, 4th Viscount Ridley
# Q328102 Matthew White Ridley, 4th Viscount Ridley
# Q355669 Alan White
# Q3569025 William White
# Q3569025 William White
# Q3610523 George White
# Q382021 Leslie White
# Q382021 Leslie White
# Q382021 Leslie White
# Q3832418 Lillias White
# Q38639102 Richard White
# Q39184824 Jason D White
# Q39184824 Jason D White
# Q39655886 Robert B. White
# Q39655886 Robert B. White
# Q42370049 Phillip J. White
# Q42370049 Phillip J. White
# Q42407086 Brett R. White
# Q42407086 Brett R. White
# Q42758692 James Michael White
# Q42879621 Travis White-schwoch
# Q43133093 Joanne White
# Q43152187 Carl W. White
# Q43152187 Carl W. White
# Q442200 Wallace Humphrey White, Jr.
# Q442200 Wallace Humphrey White, Jr.
# Q442200 Wallace Humphrey White, Jr.
# Q442202 Vanna White
# Q442202 Vanna White
# Q4468426 Jacqueline White
# Q4468426 Jacqueline White
# Q459082 John White
# Q459082 John White
# Q46040334 Michael J. White
# Q46040334 Michael J. White
# Q47696392 Stephen White
# Q49203416 Stephanie Gilbertson-White
# Q4934943 Carol White
# Q4934943 Carol White
# Q4961590 Brent White
# Q49983368 Travis A White
# Q49983368 Travis A White
# Q50607121 Blaire White
# Q50733677 Laurence White
# Q526114 Konrad VII the White
# Q5346912 Edwin White
# Q5346912 Edwin White
# Q5349851 Eirene White, Baroness White
# Q5349851 Eirene White, Baroness White
# Q5349851 Eirene White, Baroness White
# Q537531 Michael White
# Q53991 Leszek I the White
# Q5546214 George White
# Q56366543 Alice White
# Q56423106 Simon J White
# Q56423106 Simon J White
# Q56441997 Steven M White
# Q56441997 Steven M White
# Q56785261 Andrew M White
# Q56785261 Andrew M White
# Q75547361 Mary Elizabeth White
# Q75560376 Annie Mabel White
# Q75588096 Mary White
# Q75634603 Hans Thomas Fell White
# Q75634603 Hans Thomas Fell White
# Q75671126 Edith Annie White
# Q75671126 Edith Annie White
# Q75726128 Joan Olive White
# Q75754030 Marguérite Isabelle White
# Q75800297 James White Minchin
# Q75820640 Ann White
# Q75889643 Martha White
# Q75889643 Martha White
# Q75930494 Godfrey White FitzHerbert
# Q75932436 Grace White
# Q75978057 Robert Grove White
# Q75978380 James White
# Q76010875 James Grove-White
# Q76012586 Rebecca White
# Q76012597 Richard Blair White
# Q76097676 Robert W. White
# Q76102890 George Arthur Wellesley Hallifax White
# Q76135383 Thomas Holt-White
# Q7614290 Steve White
# Q76183124 Richard White
# Q76183124 Richard White
# Q76183124 Richard White
# Q76183124 Richard White
# Q76212459 Robert Holmes White
# Q76212610 Taylor White
# Q76212617 Taylor White
# Q76212638 Louis Arthur Taylor White
# Q76212705 William White
# Q76212705 William White
# Q76250626 Thomas White
# Q76279287 Edmund Richard Manwaring-White
# Q76279289 Edmund Roger Manwaring White
# Q76279289 Edmund Roger Manwaring White
# Q76285664 George Geoffrey Gundry-White
# Q76289085 Rose Hannah White
# Q76289085 Rose Hannah White
# Q76294927 Margaret Jane White
# Q76312900 Julia Lucy White
# Q76312900 Julia Lucy White
# Q7647761 Susan Dorothea White
# Q7839484 Trevor White
# Q7839484 Trevor White
# Q7945886 W. Paul White
# Q7945886 W. Paul White
# Q7945886 W. Paul White
# Q7945886 W. Paul White
# Q7966404 Walter White
# Q8020275 William White
# Q81226076 Patrick White
# Q82548386 Chris W White
# Q82548386 Chris W White
# Q862661 Bill White
# Q862661 Bill White
# Q862661 Bill White
# Q86400125 Ian M White
# Q86400125 Ian M White
# Q86882646 Brandi M White
# Q86882646 Brandi M White
# Q86961902 Mark White
# Q86990584 Easton R White
# Q86990584 Easton R White
# Q87279818 Naomi White
# Q87594749 Peter J White
# Q87594749 Peter J White
# Q87755435 André O White
# Q87784629 J Wilson White
# Q87853893 Paul White
# Q87910530 Ryan J White
# Q87910530 Ryan J White
# Q88196288 Michelle C White
# Q88196288 Michelle C White
# Q89426602 R James White
# Q89815124 Kristi M Crowe-White
# Q89815124 Kristi M Crowe-White
# Q90178387 Hannah J. White
# Q90178387 Hannah J. White
# Q90178387 Hannah J. White
# Q91698409 Stephen D White
# Q91698409 Stephen D White
# Q956275 Josh White
# Q956275 Josh White
# Q96076695 Abijah White
# Q96199514 Mary White
# Q96216849 Elizabeth White
# Q99880199 William Thomas White
# Q101550970 Louise G. White
# Q101550970 Louise G. White
# Q101840120 Lieut. Daniel White
# Q104151097 Danny White
# Q104151097 Danny White
# Q105489041 Benjamin Horace White
# Q105489041 Benjamin Horace White
# Q105489041 Benjamin Horace White
# Q105489041 Benjamin Horace White
# Q106594121 Horace C. White
# Q106594121 Horace C. White
# Q106594121 Horace C. White
# Q106594121 Horace C. White
# Q108160363 Thomas White
# Q109410840 Thomas Henry White
# Q111600356 Jordan D. White
# Q111600356 Jordan D. White
# Q1146031 Steve White
# Q1146031 Steve White
# Q12789755 George Patrick Demaine Blacker
# Q16007756 Carlos Blacker
# Q16007756 Carlos Blacker
# Q16106882 Jim Blacker
# Q16644024 Irwin R. Blacker
# Q16943939 Beaver Henry Blacker
# Q16943939 Beaver Henry Blacker
# Q16943939 Beaver Henry Blacker
# Q17421309 Harold Blacker
# Q17421309 Harold Blacker
# Q17659513 Kate Blacker
# Q18527210 George Blacker
# Q18527210 George Blacker
# Q20921983 Anthony Blacker Elliott
# Q21069715 William Blacker
# Q21069715 William Blacker
# Q21457612 Elva Joan Blacker
# Q21457612 Elva Joan Blacker
# Q21546716 William Blacker
# Q21557022 Stewart William Blacker Menaul
# Q23945399 Ann Thetis Blacker
# Q2404457 Terence Blacker
# Q26997669 Stanley Blacker
# Q29018108 Philip Blacker
# Q30056668 William Blacker
# Q33059942 Theodosia Blacker, Lady Monson
# Q43752660 George Blacker Morgan
# Q44711039 Dane Blacker
# Q47118075 Mae Blacker Freeman
# Q5055960 Cecil Blacker
# Q5055960 Cecil Blacker
# Q5055960 Cecil Blacker
# Q5055960 Cecil Blacker
# Q5055960 Cecil Blacker
# Q5055960 Cecil Blacker
# Q5141660 Coit D. Blacker
# Q5231442 David Blacker
# Q53493146 William Blacker
# Q537504 Charles Blacker Vignoles
# Q53844004 John Blacker
# Q5537022 George Blacker
# Q5537022 George Blacker
# Q5537022 George Blacker
# Q5711602 Augusto Blacker Miller
# Q60788757 Stewart Blacker
# Q6181125 Jeremy Blacker
# Q63163380 Ernest Blacker Vignoles
# Q63163380 Ernest Blacker Vignoles
# Q63921904 Hayley Patricia Blacker-Smith
# Q64684659 Thomas S Blacker
# Q64684659 Thomas S Blacker
# Q66816378 Deborah Blacker
# Q7172841 Peter Blacker
# Q7172841 Peter Blacker
# Q7422103 Sarah Blacker
# Q75257159 Diana Mary Blacker
# Q75277905 Henry Barre Blacker Beresford
# Q75284246 Theodosia Blacker
# Q75284249 Latham Blacker
# Q75285327 Letitia Blacker
# Q75285328 William Blacker
# Q75311302 St. John Thomas Blacker-Douglas
# Q75311303 Maxwell Vandeleur Blacker-Douglas
# Q75311303 Maxwell Vandeleur Blacker-Douglas
# Q75311306 Robert St. John Blacker-Douglas
# Q75311307 Charles Maxwell Blacker-Douglas
# Q75311309 Alice Florence Blacker-Douglas
# Q75311310 St. John Douglas Stewart Blacker-Douglas
# Q75311313 Emily Theodosia Blacker-Douglas
# Q75336302 Stewart Ward William Blacker
# Q75357185 Latham Valentine Stewart Blacker
# Q75357187 Latham Charles Miller Blacker
# Q75357187 Latham Charles Miller Blacker
# Q75490024 Fiona Stewart-Blacker
# Q75490024 Fiona Stewart-Blacker
# Q75490026 Patrick Stewart-Blacker
# Q75516213 Henry Blacker Shakespear Miles
# Q75528669 Norman Valentine Blacker
# Q75528677 Philip Blacker
# Q75553211 Murray McGregor Blacker
# Q75553213 Theodosia Violet Blacker
# Q75553213 Theodosia Violet Blacker
# Q75581450 Joan Olive Blacker
# Q75632450 Grace Blacker
# Q75632452 St. John Blacker
# Q75632452 St. John Blacker
# Q75636548 Susan Blacker
# Q75653518 Ellen Letitia Blacker
# Q75653519 Hannah Dorothea Blacker
# Q75653519 Hannah Dorothea Blacker
# Q75653521 Jane Mary Blacker
# Q75653522 Edward Blacker
# Q75653524 Letitia Blacker
# Q75653525 Jane Blacker
# Q75653526 Hannah Blacker
# Q75653527 Henry Blacker
# Q75653527 Henry Blacker
# Q75653528 George Blacker
# Q75653528 George Blacker
# Q75653529 Eliza Blacker
# Q75653532 Barbara Blacker
# Q75653535 Martha Blacker
# Q75653536 Alicia Blacker
# Q75653540 Jane Blacker
# Q75653546 Lucinda Blacker
# Q75653553 George Blacker
# Q75653553 George Blacker
# Q75653556 Stewart Blacker
# Q75653558 Eliza Hill Blacker
# Q75653563 Hester Anne Blacker
# Q75653565 Sophia Mary Blacker
# Q75653567 Stewart Blacker
# Q75653567 Stewart Blacker
# Q75653568 James Stewart Blacker
# Q75653568 James Stewart Blacker
# Q75653573 Letitia Blacker
# Q75653576 Sophia Blacker
# Q75653581 Eliza Blacker
# Q75653585 Louisa Blacker
# Q75653588 Caroline Blacker
# Q75653599 William Robert George Blacker
# Q75653601 Edward Carew Blacker
# Q75653607 William Desmond Blacker
# Q75653608 Terence Fitzroy Blacker
# Q75653610 Betty Mary Blacker
# Q75673976 William Blacker Bennett
# Q75783938 Latham Blacker Knox
# Q75926396 Cecil Frances Ann Anne Blacker Smyly
# Q75950251 William Blacker
# Q75950251 William Blacker
# Q75950253 Marjorie Mary Blacker
# Q75986102 Julia Adelaide Blacker
# Q75992884 Stewart Blacker Studdert
# Q76031226 Frederick Henry Blacker
# Q76031226 Frederick Henry Blacker
# Q76105043 Cecil Francis Blacker
# Q76105044 William Frederick Blacker
# Q76105044 William Frederick Blacker
# Q76139134 St. John Blacker
# Q7615730 Stewart Blacker
# Q76209674 John Nunn Blacker Woodroffe
# Q76209674 John Nunn Blacker Woodroffe
# Q76287857 Daisy Peel Blacker
# Q76293178 Catherine Blacker
# Q76293179 Latham Blacker
# Q76370753 Martha Theodosia Blacker
# Q7910936 Valentine Blacker
# Q8005589 William Blacker
# Q83689619 Maxwell Blacker
# Q83689619 Maxwell Blacker
# Q86825901 Katy-Ann Blacker
# Q87623239 Deborah Blacker
# Q87957500 Caren J Blacker
# Q87957500 Caren J Blacker
# Q89401426 David Blacker
# Q91983340 Kara J Blacker
# Q91983340 Kara J Blacker
# Q94542329 Harry Blacker
# Q94746374 Carola Blacker
# Q96089174 Peter C Blacker
# Q96089174 Peter C Blacker
# Q99193206 Stephanie Blacker
# Q99526840 Eddie Blacker
# Q1992839 Nina Queer
# Q3180162 Joe Queer
# Q101530668 Henry Guinand, of Calcutta
# Q24066841 Calcutta
# Q6036132 Mónica Calcutta Stormenzan
# Q6036132 Mónica Calcutta Stormenzan
# Q110141227 Elizabeth Allison Maroon
# Q112157706 Candy Campbell - The Maroon Doll
# Q112157706 Candy Campbell - The Maroon Doll
# Q112431383 Joseph C. Maroon
# Q1575172 Patrick Maroon
# Q21932009 Joseph Maroon
# Q24324358 Mary Elizabeth Maroon
# Q4773011 Anthony Maroon
# Q5225044 Darren Maroon
# Q5495566 Fred J. Maroon
# Q5495566 Fred J. Maroon
# Q57960568 Elizabeth Maroon
# Q60790349 Davy the Maroon
# Q91502952 Christopher R Maroon
# Q91502952 Christopher R Maroon
# Q274041 Nanny of the Maroons
# Q274041 Nanny of the Maroons
# Q106501394 Anne de Villeneuve, Marquise de Trans
# Q16186021 Antoine de Villeneuve de Trans
# Q98070689 Rikke Trans Ebbekær Jensen
# Q113459766 Romée Villeneuve-Trans
# Q4202472 John the Dwarf
# Q106738083 Dwarf Mamba
# Q7718307 The Black Dwarf
# Q5648507 Hank the Angry Drunken Dwarf
# Q1948021 Norton Knatchbull, 3rd Earl Mountbatten of Burma
# Q1948021 Norton Knatchbull, 3rd Earl Mountbatten of Burma
# Q2084789 Phani Burma
# Q271995 Edwina Mountbatten, Countess Mountbatten of Burma
# Q271995 Edwina Mountbatten, Countess Mountbatten of Burma
# Q30323763 Penelope Knatchbull, Countess Mountbatten of Burma
# Q30323763 Penelope Knatchbull, Countess Mountbatten of Burma
# Q30323763 Penelope Knatchbull, Countess Mountbatten of Burma
# Q336691 Patricia Knatchbull, 2nd Countess Mountbatten of Burma
# Q336691 Patricia Knatchbull, 2nd Countess Mountbatten of Burma
# Q59553409 Nicole E Burma
# Q59553409 Nicole E Burma
# Q96576501 Sandeep Burma
# Q22826839 Sanjay Kumar Das Burma
# Q107086476 Bikramdeba Burma
# Q107086476 Bikramdeba Burma
# Q13077938 Thathanabaing of Burma
# Q88864781 Pradeep Kumar Burma
# Q12085778 Vasyl Burma
# Q6083386 Metin Burma
# Q87820316 Brent Race
# Q47314478 Eleanor Race Mackey
# Q87599059 Paul R Race
# Q87599059 Paul R Race
# Q57022392 Marco Race
# Q84744313 Nicholas J Race
# Q84744313 Nicholas J Race
# Q701810 Race Wong
# Q707647 Harley Race
# Q707647 Harley Race
# Q56434031 Race Diloreto
# Q7273404 R.R. Race
# Q7273404 R.R. Race
# Q7273404 R.R. Race
# Q85945416 Nicholas Race
# Q60642589 C P Race
# Q76241833 Ellen Race Shales
# Q12356437 Vesna Skaljer-Race
# Q8057916 Young American Primitive
# Q84085663 Welsh Primitive
# Q12293932 Slave Makedonski
# Q128487 Slave Ǵorǵo Dimoski
# Q54599086 Slave
# Q61063039 Slave Nikolov
# Q61896511 Slave D. Hadžišče
# Q22771412 Slave Ezerov
# Q102052366 Slave Boiceff
# Q27533261 Slave Trajkoski
# Q106617914 Slave Atanasovki
# Q20570432 Slave Nikolovski-Katin
# Q6395310 Slave Banar
# Q104190518 Slave woman
# Q108762047 Sa'd, Slave of Amr ibn Khalid
# Q12293931 Slave Ivanov
# Q7539140 Slave Dimitrov
# Q7539167 Slave Stojanovic
# Q95685593 The Indigenous Famous Six
# Q98077086 Gerardo III de Métis
# Q98077087 Gerardo II de Métis
# Q98077164 Ricardo de Métis
# Q102168799 Roger Tribe
# Q18158933 Kerry Tribe
# Q55875789 Rachel Tribe
# Q55875789 Rachel Tribe
# Q55875789 Rachel Tribe
# Q75402513 William Tribe
# Q75402513 William Tribe
