# %%
import json
import re
import csv

# %% [markdown]
# #### Reading query terms

# %%
# EN
with open('query_terms_cont_en.json','r') as jf:
    query_terms_cont_en = json.load(jf)

# %%
# NL
with open('query_terms_cont_nl.json','r') as jf:
    query_terms_cont_nl = json.load(jf)

# %% [markdown]
# #### Reading the AAT EN subgraph in json

# %%
with open('aat/aat_subgraph_en.json','r') as jf:
    aat_subgraph_en = json.load(jf)

# %%
len(aat_subgraph_en['results']['bindings'])

# %% [markdown]
# #### Reading the AAT NL subgraph in json

# %%
with open('/Users/anesterov/WM/aat/aat_subgraph_nl.json','r') as jf:
    aat_subgraph_nl = json.load(jf)

# %%
len(aat_subgraph_nl['results']['bindings'])

# %% [markdown]
# #### Functions to parse the json file

# %%
def get_entity_info_aat(entity_id:str, aat_json:dict) -> dict:
    '''
    Get the values of prefLabel (str), altLabel (list),
    prefLabel_comment (str), altLabel_comment(list),
    scopeNote (str)
    '''
    results = {}
    results['entity'] = entity_id
    altLabel_list = []
    altLabel_comment_list = []
    results['scopeNote'] = ''
    results['prefLabel_comment'] = ''
    
    for triple in aat_json["results"]["bindings"]:
        if entity_id in triple['Subject']['value']:
            
            # prefLabel
            if 'prefLabel' in triple['Predicate']['value']:
                for triple_t in aat_json["results"]["bindings"]:
                    if triple_t['Subject']['value'] == triple['Object']['value']:
                        if 'literalForm' in triple_t['Predicate']['value']:
                            results['prefLabel'] = triple_t['Object']['value']
                        # prefLabel comment
                        if 'comment' in triple_t['Predicate']['value']:
                            results['prefLabel_comment'] = triple_t['Object']['value']
                        
            # altLabel
            if 'altLabel' in triple['Predicate']['value']:
                for triple_t in aat_json["results"]["bindings"]:
                    if triple_t['Subject']['value'] == triple['Object']['value']:
                        if 'literalForm' in triple_t['Predicate']['value']:
                            altLabel_list.append(triple_t['Object']['value'])
                        # altLabel comment
                        if 'comment' in triple_t['Predicate']['value']:
                            altLabel_comment_list.append(triple_t['Object']['value'])
                            
            # scopeNote
            if 'scopeNote' in triple['Predicate']['value']:
                for triple_t in aat_json["results"]["bindings"]:
                    if triple_t['Subject']['value'] == triple['Object']['value']:
                        results['scopeNote'] = triple_t['Object']['value']
                            
            results['altLabel'] = altLabel_list
            results['altLabel_comment'] = altLabel_comment_list
                        
    return results

# %%
def find_term_in_literal_aat(query_term:str, aat_json:dict) -> list:
    '''
    Searchers for a term in the literal values of properties:
    prefLabel, altLabel, rdfs comment (for prefLabel and altLabel), and scopeNote
    Returns a list of dicts with an entity URI and the property name in the literal value of which the term was found
    '''
    
    list_of_results = []
    
    for triple in aat_json["results"]["bindings"]:
        
        if triple['Object']['type'] == 'literal' \
        and len(re.findall(f'\\b{query_term}\\b',triple['Object']['value'],re.IGNORECASE)) > 0:
            
            results_per_hit = {}
            results_per_hit['query_term'] = query_term
            results_per_hit['aat_uri'] = ''
            
            # if a term found in scopeNote
                    
            if 'rdf-syntax' in triple['Predicate']['value']:
                results_per_hit['found_in'] = 'scopeNote'
                for triple_t in aat_json["results"]["bindings"]:
                    if triple_t['Object']['value'] == triple['Subject']['value']:
                        # getting entity URI
                        entity = triple_t['Subject']['value'].split('/')[-1]
                        
            # if a term found in pref or alt labels
            
            if 'literalForm' in triple['Predicate']['value']:
                for triple_t in aat_json["results"]["bindings"]:
                    if triple_t['Object']['value'] == triple['Subject']['value']:
                        # getting entity URI
                        entity = triple_t['Subject']['value'].split('/')[-1]
                        # altLabel or prefLabel 
                        if 'altLabel' in triple_t['Predicate']['value']:
                            results_per_hit['found_in'] = 'altLabel'
                        if 'prefLabel' in triple_t['Predicate']['value']:
                            results_per_hit['found_in'] = 'prefLabel'
                        
            # if a term found in rdfs comment
            
            if 'comment' in triple['Predicate']['value']:
                for triple_t in aat_json["results"]["bindings"]:
                    if triple_t['Object']['value'] == triple['Subject']['value']:
                        # getting entity URI
                        entity = triple_t['Subject']['value'].split('/')[-1]
                        # comment to altLabel or prefLabel
                        if 'altLabel' in triple_t['Predicate']['value']:
                            results_per_hit['found_in'] = 'altLabel_comment'
                        if 'prefLabel' in triple_t['Predicate']['value']:
                            results_per_hit['found_in'] = 'prefLabel_comment'
            
            results_per_hit['aat_uri'] = entity
            
            entity_info = get_entity_info_aat(entity, aat_json)
            
            results_per_hit['prefLabel'] = entity_info['prefLabel']
            results_per_hit['prefLabel_comment'] = entity_info['prefLabel_comment']
            results_per_hit['altLabel'] = entity_info['altLabel']
            results_per_hit['altLabel_comment'] = entity_info['altLabel_comment']
            results_per_hit['scopeNote'] = entity_info['scopeNote']
            
            list_of_results.append(results_per_hit)
            
    return list_of_results

# %% [markdown]
# ### Querying EN subgraph

# %%
# querying all the terms takes approx 50 min

result_dict_aat_en = {}

for lemma, wordforms in query_terms_cont_en.items():
    
    list_of_query_terms = []
    list_of_query_terms.append(lemma)
    list_of_query_terms.extend(wordforms)
    
    for query_term in list_of_query_terms:
        result_dict_aat_en[query_term] = find_term_in_literal_aat(query_term,aat_subgraph_en)
    
    print(lemma)

# %%
# saving the query results EN

with open('aat_en_query_results.json', 'w') as jf:
    json.dump(result_dict_aat_en, jf)

# %% [markdown]
# ### Querying NL subgraph

# %%
result_dict_aat_nl = {}

for lemma, wordforms in query_terms_cont_nl.items():
    
    list_of_query_terms = []
    list_of_query_terms.append(lemma)
    list_of_query_terms.extend(wordforms)
    
    for query_term in list_of_query_terms:
        result_dict_aat_nl[query_term] = find_term_in_literal_aat(query_term,aat_subgraph_nl)
    
    print(lemma)

# %%
# saving the query results NL

with open('aat_nl_query_results.json', 'w') as jf:
    json.dump(result_dict_aat_nl, jf)

# %%
import gzip

# %%
import json

# %%
json_str = json_bytes.decode('utf-8')
data = json.loads(json_str)

# %%
with gzip.open('/Users/anesterov/WM/aat/test_nl.json', 'w') as fout:
    fout.write(json.dumps(aat_subgraph_nl).encode('utf-8'))

# %%
with gzip.open('/Users/anesterov/WM/aat/test_nl.json', 'r') as fin:
    data = json.loads(fin.read().decode('utf-8'))

# %%
data
# Out:
# {'head': {'vars': ['Subject', 'Predicate', 'Object']},
#  'results': {'bindings': [{'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300189559'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000496747-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300189559'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/91954'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000496747-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'mannelijk'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/91954'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Verwijst naar het geslacht dat normaal gesproken bij de voortplanting spermacellen of mannelijke geslachtscellen produceert.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300189557'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000496746-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300189557'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/91953'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000496746-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'vrouwelijk'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/91953'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Verwijst naar het geslacht dat normaal gesproken eieren of vrouwelijke geslachtscellen produceert.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006495'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467278-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006495'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000290378-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006495'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/94957'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467278-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'scholen (gebouwen)'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000290378-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'school'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/94957'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Gebouwen of groepen gebouwen die zijn bestemd voor het geven van onderwijs.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006495'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467280-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467280-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'onderwijsgebouw'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006495'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467281-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467281-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'onderwijsgebouwen'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006495'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467282-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467282-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'schoolgebouwen'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300310404'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000395712-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300310404'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/130658'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000395712-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Simiiformes (infraorde)'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/130658'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Infraorde van acht levende families apen en zes fossiele families en hun verwanten. De soorten uit deze infraorde ontstonden in het Vroeg-Mioceen.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300386984'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000837250-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300386984'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000837251-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300386984'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/155242'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000837250-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'verlaten complexen'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000837251-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'verlaten complex'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/155242'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Complexen, dat wil zeggen verzamelingen gebouwen, andere constructies en/of open ruimten, die voorheen in gebruik waren maar nu door de vroegere inwoners verlaten zijn.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006562'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467310-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006562'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467311-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300006562'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/94968'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467310-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'joodse scholen'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000467311-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'joodse school'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/94968'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': "Wordt gebruikt voor scholen voor kinderen waar joodse onderwerpen, de Hebreeuwse taal of beide worden onderwezen, meestal in een synagoge en bestuurd onder conservatief of hervormd-joodse auspiciën. Gebruik 'talmoedscholen' voor yeshivas, orthodox-joodse dagscholen."}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300041563'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000482914-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300041563'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000482915-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300041563'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/81426'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000482914-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'sportprenten'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000482915-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'sportprent'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/81426'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Prenten met onderwerpen als jagen, schieten en wedlopen, populair in de 18e en 19e eeuw.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404677'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000775663-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404677'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/148381'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000775663-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'gaa'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/148381'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': "Verwijst in Japanse cultuur naar namen die door kunstenaars worden gebruikt in plaats van hun voornaam. Een kunstenaar kan meerdere 'gō' hebben\x8d; Hokusai bijvoorbeeld gebruikte 30 van dergelijke namen."}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300004591'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000004591-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300004591'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000288605-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300004591'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/99585'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000004591-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'antiparabemata'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000288605-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'antiparabema'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/99585'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Kapellen aan de westkant van Byzantijnse kerken, vooral van het Armeense type.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300387523'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000838050-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300387523'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000838048-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300387523'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/155739'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000838050-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'oude centra'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000838048-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'oude centrum'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/155739'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Delen van steden die oorspronkelijk het centrum van de historische nederzetting waren, met name wanneer het centrum van de huidige stad ergens anders is.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/
'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300379581'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000835035-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300379581'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/153530'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000835035-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'waterstof'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/153530'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Niet-metallisch scheikundig element (H). Het is een kleurloos, reukloos, smaakloos gas en is het lichtste scheikundige element. Het wordt gebruikt in raketbrandstof en ballonnen. De belangrijkste verbinding van waterstof (met zuurstof) is water.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300195663'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
# ...
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840479-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404282'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157227'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840479-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'navolger van'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157227'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Qualifier die gebruikt wordt voor een werk van een onbekende maker, wiens stijl sterk beïnvloed is door de genoemde kunstenaar of architect, en die gelijktijdig met of kort na die kunstenaar leeft, maar niet noodzakelijkerwijs zijn of haar leerling is (bijvoorbeeld: navolger van Hokusai).'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404286'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840483-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404286'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157231'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840483-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'naar'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157231'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Qualifier die gebruikt wordt voor een werk van een onbekende maker die een kopie heeft gemaakt van een bekend werk van de genoemde kunstenaar.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404818'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000775868-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404818'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/148635'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000775868-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'metamorfose (biologische gebeurtenis)'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/148635'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Acties of processen als gevolg van de verandering van de vorm van een dier of delen ervan tijdens postembryonale ontwikkeling. De term wordt gebruikt voor het transformatieproces van een onrijpe vorm naar een andere, volwassen vorm, een proces dat veel insecten en andere ongewervelde dieren tijdens het volwassen worden ondergaan, en ook sommige gewervelde dieren (bijvoorbeeld kikkers). \r\r\n'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404314'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840520-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404314'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157256'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840520-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'parthenogenese'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157256'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'In modern gebruik: voortplanting uit een onbevruchte gameet. Vindt hoofdzakelijk plaats onder de ongewervelden en lagere planten, maar soms ook bij bepaalde gewervelden, zoals vogels en reptielen, die zich normaliter seksueel voortplanten. De term werd in het verleden ook gebruikt voor andere vormen van aseksuele voortplanting, zoals binaire deling of knopvorming.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404334'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840551-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404334'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840552-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404334'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157274'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840551-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'fonetische transcripties'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840552-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'fonetische transcriptie'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157274'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Transcripties die gericht zijn op de uitspraak van de getranscribeerde woorden of tekst. Dit kan bijvoorbeeld het gebruik van fonetische symbolen als afkorting voor een fonetische beschrijving behelzen; sommige allofonen kunnen met specifieke symbolen worden aangeduid, of de symbolen kunnen verwijzen naar bepaalde fonemen, als een meer beperkte set categorieën gewenst is.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404364'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840591-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404364'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157300'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840591-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'flashgeheugen'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157300'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Een niet-vluchtige vorm van geheugenopslag, die geen bewegende onderdelen zoals roterende magnetische of optische platen vereist en data opslaat in blokken in plaats van bytes.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300137869'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000493032-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300137869'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000493033-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300137869'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/92556'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000493032-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'bidbankjes'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000493033-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'bidbankje'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/92556'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Kussens, krukjes of plankjes om op te knielen, die vaak vastzitten aan de kerkbanken.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300137869'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000643148-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000643148-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'bidbanken'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300137869'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000643149-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000643149-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'bidbank'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404241'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000642272-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404241'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000642273-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404241'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/133342'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000642272-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'reliekbrieven'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000642273-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'reliekbrief'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/133342'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'Echtheidscertificaat bij een reliek, met attestnummer en tekst over herkomst en echtheid van de reliek, ondertekend door een hooggeplaatste geestelijke.'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404419'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000643868-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404419'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157343'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000643868-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl', 'type': 'literal', 'value': 'DOS'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157343'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#value'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': "Algemene naam voor een aantal computerbesturingssystemen voor pc's; verschillende, ongerelateerde schijfbesturingssystemen voor microcomputers hadden de afkorting 'DOS' (Disk Operating System) in hun naam. Een voorbeeld was MS-DOS, dat tussen 1981 en 1985 de markt voor IBM-pc's en daarmee compatibele computers overheerste."}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404507'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840774-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404507'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840775-nl'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/300404507'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#scopeNote'},
#     'Object': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/scopeNote/157427'}},
#    {'Subject': {'type': 'uri',
#      'value': 'http://vocab.getty.edu/aat/term/1000840774-nl'},
#     'Predicate': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#literalForm'},
#     'Object': {'xml:lang': 'nl',
#      'type': 'literal',
#      'value': 'alternatieve data'}},
#    ...]}}

# %%
# gzip aat subgraphs

# %%
# Importing LODlitParser AAT module 
# this code is taken from
# https://stackoverflow.com/questions/67631/how-can-i-import-a-module-dynamically-given-the-full-path
import importlib.util
import sys
spec = importlib.util.spec_from_file_location("LODlitParser.aat", "/Users/anesterov/reps/LODlit/LODlitParser/aat.py")
aat = importlib.util.module_from_spec(spec)
sys.modules["LODlitParser.aat"] = aat
spec.loader.exec_module(aat)

# %%
aat._get_entity_info('300189559','nl')
# Out:
# {'entity': '300189559',
#  'scopeNote': 'Verwijst naar het geslacht dat normaal gesproken bij de voortplanting spermacellen of mannelijke geslachtscellen produceert.',
#  'prefLabel_comment': '',
#  'prefLabel': 'mannelijk',
#  'altLabel': [],
#  'altLabel_comment': []}

# %%
aat.find_term_in_literals('aboriginals','en')
# Out:
# [{'query_term': 'aboriginals',
#   'aat_uri': '300438772',
#   'found_in': 'scopeNote',
#   'prefLabel': 'Amis',
#   'prefLabel_comment': '',
#   'altLabel': ['Pangcah'],
#   'altLabel_comment': [],
#   'scopeNote': 'Cultures and styles of the Amis people lived in Taiwan. The Amis people refer to themselves in two ways: Pangcah meaning “we people” is used in regions north of Taitung, and Amis meaning “northerners” is used in the south. The denomination has to do with routes of migration and interaction among tribes. The Chinese term came to adapt Amis. The Amis territory stretches from the Qilai plain to the Hengchun peninsula, where the Amis people develop an agrarian culture intricately rooted in the low lands of Taiwan’s eastern valley and coastal plains. The Amis has the largest population of aboriginals in Taiwan.There are three subcategories of the Amis people based on geographical and cultural-linguistic differences: The Northern group of “Nanshi” Amis, the Middle group of “Xiuguluan” Amis and coastal Amis, and the Southern group of “Falangaw” Amis and Hengchun Amis.The property inheritance of the Amis is matrilineal and traditional matrimony follows the rule of mikadafo which marries Amis men into the brides’ homes. The Amis tribe is co-governed by clan chiefs, who assign responsibilities and tasks to male members of different age classes. The Harvest Festival, known as Malalikid, is the most important celebration which unifies traditional beliefs, social structure and tribal identity.'}]
